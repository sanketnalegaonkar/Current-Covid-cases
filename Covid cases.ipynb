# %%
#Installing covid

pip install covid
# Out:
# Collecting covid
#   Downloading https://files.pythonhosted.org/packages/59/73/a56355a172dcc3725f4af48160861d157ff69173670ee9499eb2d965d4e9/covid-2.3.0.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pydantic (from covid)
#   Downloading https://files.pythonhosted.org/packages/13/8f/19f7c3897b62180f1648bb2f4e1c88ded99fdb3531a41baa5f89b61e9c21/pydantic-1.6-cp37-cp37m-win_amd64.whl (1.6MB)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from covid) (4.8.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from covid) (2.22.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->covid) (1.9.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->covid) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->covid) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->covid) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->covid) (3.0.4)
# Building wheels for collected packages: covid
#   Building wheel for covid (PEP 517): started
#   Building wheel for covid (PEP 517): finished with status 'done'
#   Created wheel for covid: filename=covid-2.3.0-cp37-none-any.whl size=8448 sha256=ee860afa37369eb080cb1486487f411fbd7a85c1219cee51e9024da62c49b204
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\77\cd\8a\87daba9dc6274aa4b705f29698faeafd0f51af78e29e984c1a
# Successfully built covid
# Installing collected packages: pydantic, covid
# Successfully installed covid-2.3.0 pydantic-1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
#Get all data

from covid import Covid

covid = Covid()
covid.get_data()
# Out:
# [{'id': '18',
#   'country': 'US',
#   'confirmed': 3431574,
#   'active': 2290820,
#   'deaths': 136466,
#   'recovered': 1049098,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1594787679000},
#  {'id': '22',
#   'country': 'Brazil',
#   'confirmed': 1926824,
#   'active': 529266,
#   'deaths': 74133,
#   'recovered': 1323425,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1594787679000},
#  {'id': '27',
#   'country': 'India',
#   'confirmed': 936181,
#   'active': 319840,
#   'deaths': 24309,
#   'recovered': 592032,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1594787679000},
#  {'id': '14',
#   'country': 'Russia',
#   'confirmed': 738787,
#   'active': 215232,
#   'deaths': 11597,
#   'recovered': 511958,
#   'latitude': 61.524,
#   'longitude': 105.3188,
#   'last_update': 1594787679000},
#  {'id': '23',
#   'country': 'Peru',
#   'confirmed': 333867,
#   'active': 98377,
#   'deaths': 12229,
#   'recovered': 223261,
#   'latitude': -9.19,
#   'longitude': -75.0152,
#   'last_update': 1594787679000},
#  {'id': '21',
#   'country': 'Chile',
#   'confirmed': 319493,
#   'active': 23204,
#   'deaths': 7069,
#   'recovered': 289220,
#   'latitude': -35.6751,
#   'longitude': -71.543,
#   'last_update': 1594787679000},
#  {'id': '20',
#   'country': 'Mexico',
#   'confirmed': 311486,
#   'active': 29329,
#   'deaths': 36327,
#   'recovered': 245830,
#   'latitude': 23.6345,
#   'longitude': -102.5528,
#   'last_update': 1594787679000},
#  {'id': '163',
#   'country': 'South Africa',
#   'confirmed': 298292,
#   'active': 147667,
#   'deaths': 4346,
#   'recovered': 146279,
#   'latitude': -30.5595,
#   'longitude': 22.9375,
#   'last_update': 1594787679000},
#  {'id': '17',
#   'country': 'United Kingdom',
#   'confirmed': 292931,
#   'active': 246493,
#   'deaths': 45053,
#   'recovered': 1385,
#   'latitude': 55.0,
#   'longitude': -3.0,
#   'last_update': 1594787679000},
#  {'id': '97',
#   'country': 'Iran',
#   'confirmed': 262173,
#   'active': 23692,
#   'deaths': 13211,
#   'recovered': 225270,
#   'latitude': 32.427908,
#   'longitude': 53.688046,
#   'last_update': 1594787679000},
#  {'id': '19',
#   'country': 'Spain',
#   'confirmed': 256619,
#   'active': 77835,
#   'deaths': 28409,
#   'recovered': 150376,
#   'latitude': 40.463667,
#   'longitude': -3.74922,
#   'last_update': 1594787679000},
#  {'id': '28',
#   'country': 'Pakistan',
#   'confirmed': 255769,
#   'active': 77573,
#   'deaths': 5386,
#   'recovered': 172810,
#   'latitude': 30.3753,
#   'longitude': 69.3451,
#   'last_update': 1594787679000},
#  {'id': '11',
#   'country': 'Italy',
#   'confirmed': 243344,
#   'active': 12919,
#   'deaths': 34984,
#   'recovered': 195441,
#   'latitude': 41.8719,
#   'longitude': 12.5674,
#   'last_update': 1594787679000},
#  {'id': '154',
#   'country': 'Saudi Arabia',
#   'confirmed': 237803,
#   'active': 57960,
#   'deaths': 2283,
#   'recovered': 177560,
#   'latitude': 23.885942,
#   'longitude': 45.079162,
#   'last_update': 1594787679000},
#  {'id': '177',
#   'country': 'Turkey',
#   'confirmed': 214993,
#   'active': 12871,
#   'deaths': 5402,
#   'recovered': 196720,
#   'latitude': 38.9637,
#   'longitude': 35.2433,
#   'last_update': 1594787679000},
#  {'id': '7',
#   'country': 'France',
#   'confirmed': 209640,
#   'active': 100886,
#   'deaths': 30032,
#   'recovered': 78722,
#   'latitude': 46.2276,
#   'longitude': 2.2137,
#   'last_update': 1594787679000},
#  {'id': '8',
#   'country': 'Germany',
#   'confirmed': 200456,
#   'active': 6278,
#   'deaths': 9078,
#   'recovered': 185100,
#   'latitude': 51.165691,
#   'longitude': 10.451526,
#   'last_update': 1594787679000},
#  {'id': '40',
#   'country': 'Bangladesh',
#   'confirmed': 190057,
#   'active': 84406,
#   'deaths': 2424,
#   'recovered': 103227,
#   'latitude': 23.685,
#   'longitude': 90.3563,
#   'last_update': 1594787679000},
#  {'id': '24',
#   'country': 'Colombia',
#   'confirmed': 154277,
#   'active': 82681,
#   'deaths': 5787,
#   'recovered': 65809,
#   'latitude': 4.5709,
#   'longitude': -74.2973,
#   'last_update': 1594787679000},
#  {'id': '3',
#   'country': 'Canada',
#   'confirmed': 110350,
#   'active': 27793,
#   'deaths': 8845,
#   'recovered': 73713,
#   'latitude': 60.001,
#   'longitude': -95.001,
#   'last_update': 1594787679000},
#  {'id': '35',
#   'country': 'Argentina',
#   'confirmed': 106910,
#   'active': 59475,
#   'deaths': 1968,
#   'recovered': 45467,
#   'latitude': -38.4161,
#   'longitude': -63.6167,
#   'last_update': 1594787679000},
#  {'id': '146',
#   'country': 'Qatar',
#   'confirmed': 104533,
#   'active': 3223,
#   'deaths': 150,
#   'recovered': 101160,
#   'latitude': 25.3548,
#   'longitude': 51.1839,
#   'last_update': 1594787679000},
#  {'id': '4',
#   'country': 'China',
#   'confirmed': 85226,
#   'active': 617,
#   'deaths': 4642,
#   'recovered': 79967,
#   'latitude': 30.5928,
#   'longitude': 114.3055,
#   'last_update': 1594787679000},
#  {'id': '74',
#   'country': 'Egypt',
#   'confirmed': 83930,
#   'active': 54378,
#   'deaths': 4008,
#   'recovered': 25544,
#   'latitude': 26.820553,
#   'longitude': 30.802498,
#   'last_update': 1594787679000},
#  {'id': '98',
#   'country': 'Iraq',
#   'confirmed': 81757,
#   'active': 27630,
#   'deaths': 3345,
#   'recovered': 50782,
#   'latitude': 33.223191,
#   'longitude': 43.679291,
#   'last_update': 1594787679000},
#  {'id': '96',
#   'country': 'Indonesia',
#   'confirmed': 78572,
#   'active': 37226,
#   'deaths': 3710,
#   'recovered': 37636,
#   'latitude': -0.7893,
#   'longitude': 113.9213,
#   'last_update': 1594787679000},
#  {'id': '15',
#   'country': 'Sweden',
#   'confirmed': 76001,
#   'active': 70456,
#   'deaths': 5545,
#   'recovered': None,
#   'latitude': 60.1282,
#   'longitude': 18.6435,
#   'last_update': 1594787679000},
#  {'id': '73',
#   'country': 'Ecuador',
#   'confirmed': 69570,
#   'active': 33956,
#   'deaths': 5130,
#   'recovered': 30484,
#   'latitude': -1.8312,
#   'longitude': -78.1834,
#   'last_update': 1594787679000},
#  {'id': '42',
#   'country': 'Belarus',
#   'confirmed': 65269,
#   'active': 8996,
#   'deaths': 474,
#   'recovered': 55799,
#   'latitude': 53.7098,
#   'longitude': 27.9534,
#   'last_update': 1594787679000},
#  {'id': '102',
#   'country': 'Kazakhstan',
#   'confirmed': 63514,
#   'active': 25131,
#   'deaths': 375,
#   'recovered': 38008,
#   'latitude': 48.0196,
#   'longitude': 66.9237,
#   'last_update': 1594787679000},
#  {'id': '43',
#   'country': 'Belgium',
#   'confirmed': 62781,
#   'active': 35771,
#   'deaths': 9787,
#   'recovered': 17223,
#   'latitude': 50.8333,
#   'longitude': 4.469936,
#   'last_update': 1594787679000},
#  {'id': '139',
#   'country': 'Oman',
#   'confirmed': 59568,
#   'active': 21308,
#   'deaths': 273,
#   'recovered': 37987,
#   'latitude': 21.512583,
#   'longitude': 55.923255,
#   'last_update': 1594787679000},
#  {'id': '143',
#   'country': 'Philippines',
#   'confirmed': 57545,
#   'active': 35483,
#   'deaths': 1603,
#   'recovered': 20459,
#   'latitude': 12.879721,
#   'longitude': 121.774017,
#   'last_update': 1594787679000},
#  {'id': '106',
#   'country': 'Kuwait',
#   'confirmed': 56174,
#   'active': 9617,
#   'deaths': 396,
#   'recovered': 46161,
#   'latitude': 29.31166,
#   'longitude': 47.481766,
#   'last_update': 1594787679000},
#  {'id': '26',
#   'country': 'Ukraine',
#   'confirmed': 55931,
#   'active': 26481,
#   'deaths': 1429,
#   'recovered': 28021,
#   'latitude': 48.3794,
#   'longitude': 31.1656,
#   'last_update': 1594787679000},
#  {'id': '179',
#   'country': 'United Arab Emirates',
#   'confirmed': 55573,
#   'active': 9213,
#   'deaths': 335,
#   'recovered': 46025,
#   'latitude': 23.424076,
#   'longitude': 53.847818,
#   'last_update': 1594787679000},
#  {'id': '12',
#   'country': 'Netherlands',
#   'confirmed': 51362,
#   'active': 45015,
#   'deaths': 6154,
#   'recovered': 193,
#   'latitude': 52.3167,
#   'longitude': 5.55,
#   'last_update': 1594787679000},
#  {'id': '47',
#   'country': 'Bolivia',
#   'confirmed': 50867,
#   'active': 33150,
#   'deaths': 1898,
#   'recovered': 15819,
#   'latitude': -16.2902,
#   'longitude': -63.5887,
#   'last_update': 1594787679000},
#  {'id': '140',
#   'country': 'Panama',
#   'confirmed': 48096,
#   'active': 22469,
#   'deaths': 960,
#   'recovered': 24667,
#   'latitude': 8.538,
#   'longitude': -80.7821,
#   'last_update': 1594787679000},
#  {'id': '145',
#   'country': 'Portugal',
#   'confirmed': 47051,
#   'active': 13833,
#   'deaths': 1668,
#   'recovered': 31550,
#   'latitude': 39.3999,
#   'longitude': -8.2245,
#   'last_update': 1594787679000},
#  {'id': '159',
#   'country': 'Singapore',
#   'confirmed': 46630,
#   'active': 3866,
#   'deaths': 27,
#   'recovered': 42737,
#   'latitude': 1.2833,
#   'longitude': 103.8333,
#   'last_update': 1594787679000},
#  {'id': '72',
#   'country': 'Dominican Republic',
#   'confirmed': 46305,
#   'active': 22261,
#   'deaths': 910,
#   'recovered': 23134,
#   'latitude': 18.7357,
#   'longitude': -70.1627,
#   'last_update': 1594787679000},
#  {'id': '99',
#   'country': 'Israel',
#   'confirmed': 42360,
#   'active': 22324,
#   'deaths': 371,
#   'recovered': 19665,
#   'latitude': 31.046051,
#   'longitude': 34.851612,
#   'last_update': 1594787679000},
#  {'id': '144',
#   'country': 'Poland',
#   'confirmed': 38457,
#   'active': 9113,
#   'deaths': 1588,
#   'recovered': 27756,
#   'latitude': 51.9194,
#   'longitude': 19.1451,
#   'last_update': 1594787679000},
#  {'id': '29',
#   'country': 'Afghanistan',
#   'confirmed': 34740,
#   'active': 12238,
#   'deaths': 1048,
#   'recovered': 21454,
#   'latitude': 33.93911,
#   'longitude': 67.709953,
#   'last_update': 1594787679000},
#  {'id': '39',
#   'country': 'Bahrain',
#   'confirmed': 34078,
#   'active': 4214,
#   'deaths': 111,
#   'recovered': 29753,
#   'latitude': 26.0275,
#   'longitude': 50.55,
#   'last_update': 1594787679000},
#  {'id': '137',
#   'country': 'Nigeria',
#   'confirmed': 33616,
#   'active': 19070,
#   'deaths': 754,
#   'recovered': 13792,
#   'latitude': 9.082,
#   'longitude': 8.6753,
#   'last_update': 1594787679000},
#  {'id': '147',
#   'country': 'Romania',
#   'confirmed': 33585,
#   'active': 9851,
#   'deaths': 1931,
#   'recovered': 21803,
#   'latitude': 45.9432,
#   'longitude': 24.9668,
#   'last_update': 1594787679000},
#  {'id': '16',
#   'country': 'Switzerland',
#   'confirmed': 33016,
#   'active': 1248,
#   'deaths': 1968,
#   'recovered': 29800,
#   'latitude': 46.8182,
#   'longitude': 8.2275,
#   'last_update': 1594787679000},
#  {'id': '36',
#   'country': 'Armenia',
#   'confirmed': 32490,
#   'active': 11180,
#   'deaths': 581,
#   'recovered': 20729,
#   'latitude': 40.0691,
#   'longitude': 45.0382,
#   'last_update': 1594787679000},
#  {'id': '88',
#   'country': 'Guatemala',
#   'confirmed': 30872,
#   'active': 25117,
#   'deaths': 1302,
#   'recovered': 4453,
#   'latitude': 15.7835,
#   'longitude': -90.2308,
#   'last_update': 1594787679000},
#  {'id': '94',
#   'country': 'Honduras',
#   'confirmed': 28579,
#   'active': 24667,
#   'deaths': 789,
#   'recovered': 3123,
#   'latitude': 15.2,
#   'longitude': -86.2419,
#   'last_update': 1594787679000},
#  {'id': '10',
#   'country': 'Ireland',
#   'confirmed': 25670,
#   'active': 560,
#   'deaths': 1746,
#   'recovered': 23364,
#   'latitude': 53.1424,
#   'longitude': -7.6921,
#   'last_update': 1594787679000},
#  {'id': '37',
#   'country': 'Azerbaijan',
#   'confirmed': 25113,
#   'active': 8644,
#   'deaths': 319,
#   'recovered': 16150,
#   'latitude': 40.1431,
#   'longitude': 47.5769,
#   'last_update': 1594787679000},
#  {'id': '85',
#   'country': 'Ghana',
#   'confirmed': 24988,
#   'active': 3782,
#   'deaths': 139,
#   'recovered': 21067,
#   'latitude': 7.9465,
#   'longitude': -1.0232,
#   'last_update': 1594787679000},
#  {'id': '25',
#   'country': 'Japan',
#   'confirmed': 22437,
#   'active': 3327,
#   'deaths': 984,
#   'recovered': 18126,
#   'latitude': 36.204824,
#   'longitude': 138.252924,
#   'last_update': 1594787679000},
#  {'id': '31',
#   'country': 'Algeria',
#   'confirmed': 20216,
#   'active': 4893,
#   'deaths': 1028,
#   'recovered': 14295,
#   'latitude': 28.0339,
#   'longitude': 1.6596,
#   'last_update': 1594787679000},
#  {'id': '126',
#   'country': 'Moldova',
#   'confirmed': 19708,
#   'active': 6020,
#   'deaths': 655,
#   'recovered': 13033,
#   'latitude': 47.4116,
#   'longitude': 28.3699,
#   'last_update': 1594787679000},
#  {'id': '2',
#   'country': 'Austria',
#   'confirmed': 19021,
#   'active': 1239,
#   'deaths': 709,
#   'recovered': 17073,
#   'latitude': 47.5162,
#   'longitude': 14.5501,
#   'last_update': 1594787679000},
#  {'id': '156',
#   'country': 'Serbia',
#   'confirmed': 18983,
#   'active': 4574,
#   'deaths': 418,
#   'recovered': 13991,
#   'latitude': 44.0165,
#   'longitude': 21.0059,
#   'last_update': 1594787679000},
#  {'id': '133',
#   'country': 'Nepal',
#   'confirmed': 17061,
#   'active': 6695,
#   'deaths': 38,
#   'recovered': 10328,
#   'latitude': 28.1667,
#   'longitude': 84.25,
#   'last_update': 1594787679000},
#  {'id': '130',
#   'country': 'Morocco',
#   'confirmed': 16097,
#   'active': 2398,
#   'deaths': 257,
#   'recovered': 13442,
#   'latitude': 31.7917,
#   'longitude': -7.0926,
#   'last_update': 1594787679000},
#  {'id': '57',
#   'country': 'Cameroon',
#   'confirmed': 15173,
#   'active': 2886,
#   'deaths': 359,
#   'recovered': 11928,
#   'latitude': 3.848,
#   'longitude': 11.5021,
#   'last_update': 1594787679000},
#  {'id': '181',
#   'country': 'Uzbekistan',
#   'confirmed': 14085,
#   'active': 5691,
#   'deaths': 67,
#   'recovered': 8327,
#   'latitude': 41.377491,
#   'longitude': 64.585262,
#   'last_update': 1594787679000},
#  {'id': '104',
#   'country': 'Korea, South',
#   'confirmed': 13551,
#   'active': 914,
#   'deaths': 289,
#   'recovered': 12348,
#   'latitude': 35.907757,
#   'longitude': 127.766922,
#   'last_update': 1594787679000},
#  {'id': '68',
#   'country': 'Czechia',
#   'confirmed': 13341,
#   'active': 4545,
#   'deaths': 355,
#   'recovered': 8441,
#   'latitude': 49.8175,
#   'longitude': 15.473,
#   'last_update': 1594787679000},
#  {'id': '5',
#   'country': 'Denmark',
#   'confirmed': 13262,
#   'active': 291,
#   'deaths': 610,
#   'recovered': 12361,
#   'latitude': 56.2639,
#   'longitude': 9.5018,
#   'last_update': 1594787679000},
#  {'id': '64',
#   'country': "Cote d'Ivoire",
#   'confirmed': 13037,
#   'active': 6042,
#   'deaths': 87,
#   'recovered': 6908,
#   'latitude': 7.54,
#   'longitude': -5.5471,
#   'last_update': 1594787679000},
#  {'id': '107',
#   'country': 'Kyrgyzstan',
#   'confirmed': 11444,
#   'active': 7757,
#   'deaths': 149,
#   'recovered': 3538,
#   'latitude': 41.20438,
#   'longitude': 74.766098,
#   'last_update': 1594787679000},
#  {'id': '103',
#   'country': 'Kenya',
#   'confirmed': 10791,
#   'active': 7572,
#   'deaths': 202,
#   'recovered': 3017,
#   'latitude': -0.0236,
#   'longitude': 37.9062,
#   'last_update': 1594787679000},
#  {'id': '1',
#   'country': 'Australia',
#   'confirmed': 10487,
#   'active': 2448,
#   'deaths': 111,
#   'recovered': 7928,
#   'latitude': -25.0,
#   'longitude': 133.0,
#   'last_update': 1594787679000},
#  {'id': '166',
#   'country': 'Sudan',
#   'confirmed': 10417,
#   'active': 4179,
#   'deaths': 659,
#   'recovered': 5579,
#   'latitude': 12.8628,
#   'longitude': 30.2176,
#   'last_update': 1594787679000},
#  {'id': '75',
#   'country': 'El Salvador',
#   'confirmed': 10303,
#   'active': 4106,
#   'deaths': 278,
#   'recovered': 5919,
#   'latitude': 13.7942,
#   'longitude': -88.8965,
#   'last_update': 1594787679000},
#  {'id': '182',
#   'country': 'Venezuela',
#   'confirmed': 10010,
#   'active': 7243,
#   'deaths': 96,
#   'recovered': 2671,
#   'latitude': 6.4238,
#   'longitude': -66.5897,
#   'last_update': 1594787679000},
#  {'id': '13',
#   'country': 'Norway',
#   'confirmed': 9001,
#   'active': 610,
#   'deaths': 253,
#   'recovered': 8138,
#   'latitude': 60.472,
#   'longitude': 8.4689,
#   'last_update': 1594787679000},
#  {'id': '120',
#   'country': 'Malaysia',
#   'confirmed': 8729,
#   'active': 83,
#   'deaths': 122,
#   'recovered': 8524,
#   'latitude': 4.210484,
#   'longitude': 101.975766,
#   'last_update': 1594787679000},
#  {'id': '63',
#   'country': 'Costa Rica',
#   'confirmed': 8482,
#   'active': 6004,
#   'deaths': 37,
#   'recovered': 2441,
#   'latitude': 9.7489,
#   'longitude': -83.7534,
#   'last_update': 1594787679000},
#  {'id': '138',
#   'country': 'North Macedonia',
#   'confirmed': 8332,
#   'active': 3475,
#   'deaths': 389,
#   'recovered': 4468,
#   'latitude': 41.6086,
#   'longitude': 21.7453,
#   'last_update': 1594787679000},
#  {'id': '155',
#   'country': 'Senegal',
#   'confirmed': 8243,
#   'active': 2513,
#   'deaths': 150,
#   'recovered': 5580,
#   'latitude': 14.4974,
#   'longitude': -14.4524,
#   'last_update': 1594787679000},
#  {'id': '62',
#   'country': 'Congo (Kinshasa)',
#   'confirmed': 8135,
#   'active': 3997,
#   'deaths': 190,
#   'recovered': 3948,
#   'latitude': -4.0383,
#   'longitude': 21.7587,
#   'last_update': 1594787679000},
#  {'id': '80',
#   'country': 'Ethiopia',
#   'confirmed': 7969,
#   'active': 5400,
#   'deaths': 139,
#   'recovered': 2430,
#   'latitude': 9.145,
#   'longitude': 40.4897,
#   'last_update': 1594787679000},
#  {'id': '51',
#   'country': 'Bulgaria',
#   'confirmed': 7645,
#   'active': 3699,
#   'deaths': 283,
#   'recovered': 3663,
#   'latitude': 42.7339,
#   'longitude': 25.4858,
#   'last_update': 1594787679000},
#  {'id': '6',
#   'country': 'Finland',
#   'confirmed': 7301,
#   'active': 172,
#   'deaths': 329,
#   'recovered': 6800,
#   'latitude': 61.9241,
#   'longitude': 25.7482,
#   'last_update': 1594787679000},
#  {'id': '48',
#   'country': 'Bosnia and Herzegovina',
#   'confirmed': 6981,
#   'active': 3576,
#   'deaths': 226,
#   'recovered': 3179,
#   'latitude': 43.9159,
#   'longitude': 17.6791,
#   'last_update': 1594787679000},
#  {'id': '184',
#   'country': 'West Bank and Gaza',
#   'confirmed': 6764,
#   'active': 5636,
#   'deaths': 44,
#   'recovered': 1084,
#   'latitude': 31.9522,
#   'longitude': 35.2332,
#   'last_update': 1594787679000},
#  {'id': '92',
#   'country': 'Haiti',
#   'confirmed': 6727,
#   'active': 3564,
#   'deaths': 141,
#   'recovered': 3022,
#   'latitude': 18.9712,
#   'longitude': -72.2852,
#   'last_update': 1594787679000},
#  {'id': '170',
#   'country': 'Tajikistan',
#   'confirmed': 6643,
#   'active': 1255,
#   'deaths': 56,
#   'recovered': 5332,
#   'latitude': 38.861034,
#   'longitude': 71.276093,
#   'last_update': 1594787679000},
#  {'id': '89',
#   'country': 'Guinea',
#   'confirmed': 6200,
#   'active': 1211,
#   'deaths': 38,
#   'recovered': 4951,
#   'latitude': 9.9456,
#   'longitude': -9.6966,
#   'last_update': 1594787679000},
#  {'id': '82',
#   'country': 'Gabon',
#   'confirmed': 6026,
#   'active': 2505,
#   'deaths': 46,
#   'recovered': 3475,
#   'latitude': -0.8037,
#   'longitude': 11.6094,
#   'last_update': 1594787679000},
#  {'id': '124',
#   'country': 'Mauritania',
#   'confirmed': 5518,
#   'active': 2707,
#   'deaths': 147,
#   'recovered': 2664,
#   'latitude': 21.0079,
#   'longitude': -10.9408,
#   'last_update': 1594787679000},
#  {'id': '118',
#   'country': 'Madagascar',
#   'confirmed': 5343,
#   'active': 2658,
#   'deaths': 39,
#   'recovered': 2646,
#   'latitude': -18.766947,
#   'longitude': 46.869107,
#   'last_update': 1594787679000},
#  {'id': '105',
#   'country': 'Kosovo',
#   'confirmed': 5118,
#   'active': 2640,
#   'deaths': 108,
#   'recovered': 2370,
#   'latitude': 42.602636,
#   'longitude': 20.902977,
#   'last_update': 1594787679000},
#  {'id': '116',
#   'country': 'Luxembourg',
#   'confirmed': 5056,
#   'active': 750,
#   'deaths': 111,
#   'recovered': 4195,
#   'latitude': 49.8153,
#   'longitude': 6.1296,
#   'last_update': 1594787679000},
#  {'id': '70',
#   'country': 'Djibouti',
#   'confirmed': 4979,
#   'active': 180,
#   'deaths': 56,
#   'recovered': 4743,
#   'latitude': 11.8251,
#   'longitude': 42.5903,
#   'last_update': 1594787679000},
#  {'id': '58',
#   'country': 'Central African Republic',
#   'confirmed': 4356,
#   'active': 3074,
#   'deaths': 53,
#   'recovered': 1229,
#   'latitude': 6.6111,
#   'longitude': 20.9394,
#   'last_update': 1594787679000},
#  {'id': '95',
#   'country': 'Hungary',
#   'confirmed': 4258,
#   'active': 557,
#   'deaths': 595,
#   'recovered': 3106,
#   'latitude': 47.1625,
#   'longitude': 19.5033,
#   'last_update': 1594787679000},
#  {'id': '86',
#   'country': 'Greece',
#   'confirmed': 3883,
#   'active': 2316,
#   'deaths': 193,
#   'recovered': 1374,
#   'latitude': 39.0742,
#   'longitude': 21.8243,
#   'last_update': 1594787679000},
#  {'id': '65',
#   'country': 'Croatia',
#   'confirmed': 3827,
#   'active': 1149,
#   'deaths': 120,
#   'recovered': 2558,
#   'latitude': 45.1,
#   'longitude': 15.2,
#   'last_update': 1594787679000},
#  {'id': '30',
#   'country': 'Albania',
#   'confirmed': 3667,
#   'active': 1508,
#   'deaths': 97,
#   'recovered': 2062,
#   'latitude': 41.1533,
#   'longitude': 20.1683,
#   'last_update': 1594787679000},
#  {'id': '172',
#   'country': 'Thailand',
#   'confirmed': 3227,
#   'active': 78,
#   'deaths': 58,
#   'recovered': 3091,
#   'latitude': 15.870032,
#   'longitude': 100.992541,
#   'last_update': 1594787679000},
#  {'id': '135',
#   'country': 'Nicaragua',
#   'confirmed': 3147,
#   'active': 766,
#   'deaths': 99,
#   'recovered': 2282,
#   'latitude': 12.865416,
#   'longitude': -85.207229,
#   'last_update': 1594787679000},
#  {'id': '162',
#   'country': 'Somalia',
#   'confirmed': 3076,
#   'active': 1603,
#   'deaths': 93,
#   'recovered': 1380,
#   'latitude': 5.152149,
#   'longitude': 46.199616,
#   'last_update': 1594787679000},
#  {'id': '142',
#   'country': 'Paraguay',
#   'confirmed': 3074,
#   'active': 1741,
#   'deaths': 25,
#   'recovered': 1308,
#   'latitude': -23.4425,
#   'longitude': -58.4438,
#   'last_update': 1594787679000},
#  {'id': '76',
#   'country': 'Equatorial Guinea',
#   'confirmed': 3071,
#   'active': 2178,
#   'deaths': 51,
#   'recovered': 842,
#   'latitude': 1.6508,
#   'longitude': 10.2679,
#   'last_update': 1594787679000},
#  {'id': '121',
#   'country': 'Maldives',
#   'confirmed': 2801,
#   'active': 485,
#   'deaths': 14,
#   'recovered': 2302,
#   'latitude': 3.2028,
#   'longitude': 73.2207,
#   'last_update': 1594787679000},
#  {'id': '165',
#   'country': 'Sri Lanka',
#   'confirmed': 2665,
#   'active': 666,
#   'deaths': 11,
#   'recovered': 1988,
#   'latitude': 7.873054,
#   'longitude': 80.771797,
#   'last_update': 1594787679000},
#  {'id': '119',
#   'country': 'Malawi',
#   'confirmed': 2497,
#   'active': 1662,
#   'deaths': 40,
#   'recovered': 795,
#   'latitude': -13.254308,
#   'longitude': 34.301525,
#   'last_update': 1594787679000},
#  {'id': '110',
#   'country': 'Lebanon',
#   'confirmed': 2451,
#   'active': 962,
#   'deaths': 37,
#   'recovered': 1452,
#   'latitude': 33.8547,
#   'longitude': 35.8623,
#   'last_update': 1594787679000},
#  {'id': '66',
#   'country': 'Cuba',
#   'confirmed': 2432,
#   'active': 70,
#   'deaths': 87,
#   'recovered': 2275,
#   'latitude': 21.521757,
#   'longitude': -77.781167,
#   'last_update': 1594787679000},
#  {'id': '122',
#   'country': 'Mali',
#   'confirmed': 2423,
#   'active': 554,
#   'deaths': 121,
#   'recovered': 1748,
#   'latitude': 17.570692,
#   'longitude': -3.996166,
#   'last_update': 1594787679000},
#  {'id': '164',
#   'country': 'South Sudan',
#   'confirmed': 2148,
#   'active': 1774,
#   'deaths': 41,
#   'recovered': 333,
#   'latitude': 6.877,
#   'longitude': 31.307,
#   'last_update': 1594787679000},
#  {'id': '61',
#   'country': 'Congo (Brazzaville)',
#   'confirmed': 2028,
#   'active': 1392,
#   'deaths': 47,
#   'recovered': 589,
#   'latitude': -0.228,
#   'longitude': 15.8277,
#   'last_update': 1594787679000},
#  {'id': '78',
#   'country': 'Estonia',
#   'confirmed': 2015,
#   'active': 49,
#   'deaths': 69,
#   'recovered': 1897,
#   'latitude': 58.5953,
#   'longitude': 25.0136,
#   'last_update': 1594787679000},
#  {'id': '160',
#   'country': 'Slovakia',
#   'confirmed': 1908,
#   'active': 387,
#   'deaths': 28,
#   'recovered': 1493,
#   'latitude': 48.669,
#   'longitude': 19.699,
#   'last_update': 1594787679000},
#  {'id': '9',
#   'country': 'Iceland',
#   'confirmed': 1905,
#   'active': 13,
#   'deaths': 10,
#   'recovered': 1882,
#   'latitude': 64.9631,
#   'longitude': -19.0208,
#   'last_update': 1594787679000},
#  {'id': '187',
#   'country': 'Zambia',
#   'confirmed': 1895,
#   'active': 441,
#   'deaths': 42,
#   'recovered': 1412,
#   'latitude': -13.133897,
#   'longitude': 27.849332,
#   'last_update': 1594787679000},
#  {'id': '115',
#   'country': 'Lithuania',
#   'confirmed': 1875,
#   'active': 225,
#   'deaths': 79,
#   'recovered': 1571,
#   'latitude': 55.1694,
#   'longitude': 23.8813,
#   'last_update': 1594787679000},
#  {'id': '161',
#   'country': 'Slovenia',
#   'confirmed': 1859,
#   'active': 260,
#   'deaths': 111,
#   'recovered': 1488,
#   'latitude': 46.1512,
#   'longitude': 14.9955,
#   'last_update': 1594787679000},
#  {'id': '90',
#   'country': 'Guinea-Bissau',
#   'confirmed': 1842,
#   'active': 1043,
#   'deaths': 26,
#   'recovered': 773,
#   'latitude': 11.8037,
#   'longitude': -15.1804,
#   'last_update': 1594787679000},
#  {'id': '55',
#   'country': 'Cabo Verde',
#   'confirmed': 1722,
#   'active': 931,
#   'deaths': 19,
#   'recovered': 772,
#   'latitude': 16.5388,
#   'longitude': -23.0418,
#   'last_update': 1594787679000},
#  {'id': '158',
#   'country': 'Sierra Leone',
#   'confirmed': 1651,
#   'active': 397,
#   'deaths': 64,
#   'recovered': 1190,
#   'latitude': 8.460555,
#   'longitude': -11.779889,
#   'last_update': 1594787679000},
#  {'id': '113',
#   'country': 'Libya',
#   'confirmed': 1563,
#   'active': 1151,
#   'deaths': 42,
#   'recovered': 370,
#   'latitude': 26.3351,
#   'longitude': 17.228331,
#   'last_update': 1594787679000},
#  {'id': '134',
#   'country': 'New Zealand',
#   'confirmed': 1547,
#   'active': 27,
#   'deaths': 22,
#   'recovered': 1498,
#   'latitude': -40.9006,
#   'longitude': 174.886,
#   'last_update': 1594787679000},
#  {'id': '186',
#   'country': 'Yemen',
#   'confirmed': 1516,
#   'active': 402,
#   'deaths': 429,
#   'recovered': 685,
#   'latitude': 15.552727,
#   'longitude': 48.516388,
#   'last_update': 1594787679000},
#  {'id': '79',
#   'country': 'Eswatini',
#   'confirmed': 1434,
#   'active': 719,
#   'deaths': 20,
#   'recovered': 695,
#   'latitude': -26.5225,
#   'longitude': 31.4659,
#   'last_update': 1594787679000},
#  {'id': '148',
#   'country': 'Rwanda',
#   'confirmed': 1416,
#   'active': 675,
#   'deaths': 4,
#   'recovered': 737,
#   'latitude': -1.9403,
#   'longitude': 29.8739,
#   'last_update': 1594787679000},
#  {'id': '45',
#   'country': 'Benin',
#   'confirmed': 1378,
#   'active': 795,
#   'deaths': 26,
#   'recovered': 557,
#   'latitude': 9.3077,
#   'longitude': 2.3158,
#   'last_update': 1594787679000},
#  {'id': '176',
#   'country': 'Tunisia',
#   'confirmed': 1306,
#   'active': 169,
#   'deaths': 50,
#   'recovered': 1087,
#   'latitude': 33.886917,
#   'longitude': 9.537499,
#   'last_update': 1594787679000},
#  {'id': '129',
#   'country': 'Montenegro',
#   'confirmed': 1287,
#   'active': 933,
#   'deaths': 24,
#   'recovered': 330,
#   'latitude': 42.708678,
#   'longitude': 19.37439,
#   'last_update': 1594787679000},
#  {'id': '131',
#   'country': 'Mozambique',
#   'confirmed': 1268,
#   'active': 886,
#   'deaths': 9,
#   'recovered': 373,
#   'latitude': -18.665695,
#   'longitude': 35.529562,
#   'last_update': 1594787679000},
#  {'id': '101',
#   'country': 'Jordan',
#   'confirmed': 1198,
#   'active': 175,
#   'deaths': 10,
#   'recovered': 1013,
#   'latitude': 31.24,
#   'longitude': 36.51,
#   'last_update': 1594787679000},
#  {'id': '109',
#   'country': 'Latvia',
#   'confirmed': 1174,
#   'active': 121,
#   'deaths': 31,
#   'recovered': 1022,
#   'latitude': 56.8796,
#   'longitude': 24.6032,
#   'last_update': 1594787679000},
#  {'id': '136',
#   'country': 'Niger',
#   'confirmed': 1099,
#   'active': 39,
#   'deaths': 68,
#   'recovered': 992,
#   'latitude': 17.607789,
#   'longitude': 8.081666,
#   'last_update': 1594787679000},
#  {'id': '188',
#   'country': 'Zimbabwe',
#   'confirmed': 1064,
#   'active': 701,
#   'deaths': 20,
#   'recovered': 343,
#   'latitude': -19.015438,
#   'longitude': 29.154857,
#   'last_update': 1594787679000},
#  {'id': '178',
#   'country': 'Uganda',
#   'confirmed': 1040,
#   'active': 56,
#   'deaths': 0,
#   'recovered': 984,
#   'latitude': 1.373333,
#   'longitude': 32.290275,
#   'last_update': 1594787679000},
#  {'id': '52',
#   'country': 'Burkina Faso',
#   'confirmed': 1037,
#   'active': 111,
#   'deaths': 53,
#   'recovered': 873,
#   'latitude': 12.2383,
#   'longitude': -1.5616,
#   'last_update': 1594787679000},
#  {'id': '112',
#   'country': 'Liberia',
#   'confirmed': 1024,
#   'active': 534,
#   'deaths': 51,
#   'recovered': 439,
#   'latitude': 6.428055,
#   'longitude': -9.429499,
#   'last_update': 1594787679000},
#  {'id': '67',
#   'country': 'Cyprus',
#   'confirmed': 1023,
#   'active': 165,
#   'deaths': 19,
#   'recovered': 839,
#   'latitude': 35.1264,
#   'longitude': 33.4299,
#   'last_update': 1594787679000},
#  {'id': '84',
#   'country': 'Georgia',
#   'confirmed': 999,
#   'active': 114,
#   'deaths': 15,
#   'recovered': 870,
#   'latitude': 42.3154,
#   'longitude': 43.3569,
#   'last_update': 1594787679000},
#  {'id': '180',
#   'country': 'Uruguay',
#   'confirmed': 997,
#   'active': 61,
#   'deaths': 31,
#   'recovered': 905,
#   'latitude': -32.5228,
#   'longitude': -55.7658,
#   'last_update': 1594787679000},
#  {'id': '59',
#   'country': 'Chad',
#   'confirmed': 884,
#   'active': 11,
#   'deaths': 75,
#   'recovered': 798,
#   'latitude': 15.4542,
#   'longitude': 18.7322,
#   'last_update': 1594787679000},
#  {'id': '132',
#   'country': 'Namibia',
#   'confirmed': 864,
#   'active': 833,
#   'deaths': 2,
#   'recovered': 29,
#   'latitude': -22.9576,
#   'longitude': 18.4904,
#   'last_update': 1594787679000},
#  {'id': '32',
#   'country': 'Andorra',
#   'confirmed': 861,
#   'active': 6,
#   'deaths': 52,
#   'recovered': 803,
#   'latitude': 42.5063,
#   'longitude': 1.5218,
#   'last_update': 1594787679000},
#  {'id': '167',
#   'country': 'Suriname',
#   'confirmed': 801,
#   'active': 240,
#   'deaths': 18,
#   'recovered': 543,
#   'latitude': 3.9193,
#   'longitude': -56.0278,
#   'last_update': 1594787679000},
#  {'id': '100',
#   'country': 'Jamaica',
#   'confirmed': 762,
#   'active': 109,
#   'deaths': 10,
#   'recovered': 643,
#   'latitude': 18.1096,
#   'longitude': -77.2975,
#   'last_update': 1594787679000},
#  {'id': '153',
#   'country': 'Sao Tome and Principe',
#   'confirmed': 732,
#   'active': 432,
#   'deaths': 14,
#   'recovered': 286,
#   'latitude': 0.18636,
#   'longitude': 6.613081,
#   'last_update': 1594787679000},
#  {'id': '174',
#   'country': 'Togo',
#   'confirmed': 731,
#   'active': 188,
#   'deaths': 15,
#   'recovered': 528,
#   'latitude': 8.6195,
#   'longitude': 0.8248,
#   'last_update': 1594787679000},
#  {'id': '69',
#   'country': 'Diamond Princess',
#   'confirmed': 712,
#   'active': 48,
#   'deaths': 13,
#   'recovered': 651,
#   'latitude': None,
#   'longitude': None,
#   'last_update': 1594787679000},
#  {'id': '152',
#   'country': 'San Marino',
#   'confirmed': 699,
#   'active': 1,
#   'deaths': 42,
#   'recovered': 656,
#   'latitude': 43.9424,
#   'longitude': 12.4578,
#   'last_update': 1594787679000},
#  {'id': '123',
#   'country': 'Malta',
#   'confirmed': 674,
#   'active': 5,
#   'deaths': 9,
#   'recovered': 660,
#   'latitude': 35.9375,
#   'longitude': 14.3754,
#   'last_update': 1594787679000},
#  {'id': '33',
#   'country': 'Angola',
#   'confirmed': 541,
#   'active': 397,
#   'deaths': 26,
#   'recovered': 118,
#   'latitude': -11.2027,
#   'longitude': 17.8739,
#   'last_update': 1594787679000},
#  {'id': '171',
#   'country': 'Tanzania',
#   'confirmed': 509,
#   'active': 305,
#   'deaths': 21,
#   'recovered': 183,
#   'latitude': -6.369028,
#   'longitude': 34.888822,
#   'last_update': 1594787679000},
#  {'id': '169',
#   'country': 'Taiwan*',
#   'confirmed': 451,
#   'active': 4,
#   'deaths': 7,
#   'recovered': 440,
#   'latitude': 23.7,
#   'longitude': 121.0,
#   'last_update': 1594787679000},
#  {'id': '168',
#   'country': 'Syria',
#   'confirmed': 439,
#   'active': 280,
#   'deaths': 21,
#   'recovered': 138,
#   'latitude': 34.802075,
#   'longitude': 38.996815,
#   'last_update': 1594787679000},
#  {'id': '49',
#   'country': 'Botswana',
#   'confirmed': 399,
#   'active': 360,
#   'deaths': 1,
#   'recovered': 38,
#   'latitude': -22.3285,
#   'longitude': 24.6849,
#   'last_update': 1594787679000},
#  {'id': '183',
#   'country': 'Vietnam',
#   'confirmed': 373,
#   'active': 21,
#   'deaths': 0,
#   'recovered': 352,
#   'latitude': 14.058324,
#   'longitude': 108.277199,
#   'last_update': 1594787679000},
#  {'id': '125',
#   'country': 'Mauritius',
#   'confirmed': 342,
#   'active': 2,
#   'deaths': 10,
#   'recovered': 330,
#   'latitude': -20.348404,
#   'longitude': 57.552152,
#   'last_update': 1594787679000},
#  {'id': '53',
#   'country': 'Burma',
#   'confirmed': 337,
#   'active': 70,
#   'deaths': 6,
#   'recovered': 261,
#   'latitude': 21.9162,
#   'longitude': 95.956,
#   'last_update': 1594787679000},
#  {'id': '60',
#   'country': 'Comoros',
#   'confirmed': 321,
#   'active': 12,
#   'deaths': 7,
#   'recovered': 302,
#   'latitude': -11.6455,
#   'longitude': 43.3333,
#   'last_update': 1594787679000},
#  {'id': '91',
#   'country': 'Guyana',
#   'confirmed': 308,
#   'active': 135,
#   'deaths': 17,
#   'recovered': 156,
#   'latitude': 4.860416,
#   'longitude': -58.93018,
#   'last_update': 1594787679000},
#  {'id': '54',
#   'country': 'Burundi',
#   'confirmed': 269,
#   'active': 61,
#   'deaths': 1,
#   'recovered': 207,
#   'latitude': -3.3731,
#   'longitude': 29.9189,
#   'last_update': 1594787679000},
#  {'id': '128',
#   'country': 'Mongolia',
#   'confirmed': 261,
#   'active': 54,
#   'deaths': 0,
#   'recovered': 207,
#   'latitude': 46.8625,
#   'longitude': 103.8467,
#   'last_update': 1594787679000},
#  {'id': '111',
#   'country': 'Lesotho',
#   'confirmed': 256,
#   'active': 205,
#   'deaths': 3,
#   'recovered': 48,
#   'latitude': -29.609988,
#   'longitude': 28.233608,
#   'last_update': 1594787679000},
#  {'id': '77',
#   'country': 'Eritrea',
#   'confirmed': 232,
#   'active': 125,
#   'deaths': 0,
#   'recovered': 107,
#   'latitude': 15.1794,
#   'longitude': 39.7823,
#   'last_update': 1594787679000},
#  {'id': '56',
#   'country': 'Cambodia',
#   'confirmed': 165,
#   'active': 32,
#   'deaths': 0,
#   'recovered': 133,
#   'latitude': 11.55,
#   'longitude': 104.9167,
#   'last_update': 1594787679000},
#  {'id': '50',
#   'country': 'Brunei',
#   'confirmed': 141,
#   'active': 0,
#   'deaths': 3,
#   'recovered': 138,
#   'latitude': 4.5353,
#   'longitude': 114.7277,
#   'last_update': 1594787679000},
#  {'id': '175',
#   'country': 'Trinidad and Tobago',
#   'confirmed': 133,
#   'active': 1,
#   'deaths': 8,
#   'recovered': 124,
#   'latitude': 10.6918,
#   'longitude': -61.2225,
#   'last_update': 1594787679000},
#  {'id': '38',
#   'country': 'Bahamas',
#   'confirmed': 116,
#   'active': 14,
#   'deaths': 11,
#   'recovered': 91,
#   'latitude': 25.025885,
#   'longitude': -78.035889,
#   'last_update': 1594787679000},
#  {'id': '127',
#   'country': 'Monaco',
#   'confirmed': 109,
#   'active': 8,
#   'deaths': 4,
#   'recovered': 97,
#   'latitude': 43.7333,
#   'longitude': 7.4167,
#   'last_update': 1594787679000},
#  {'id': '41',
#   'country': 'Barbados',
#   'confirmed': 103,
#   'active': 6,
#   'deaths': 7,
#   'recovered': 90,
#   'latitude': 13.1939,
#   'longitude': -59.5432,
#   'last_update': 1594787679000},
#  {'id': '157',
#   'country': 'Seychelles',
#   'confirmed': 100,
#   'active': 89,
#   'deaths': 0,
#   'recovered': 11,
#   'latitude': -4.6796,
#   'longitude': 55.492,
#   'last_update': 1594787679000},
#  {'id': '46',
#   'country': 'Bhutan',
#   'confirmed': 84,
#   'active': 6,
#   'deaths': 0,
#   'recovered': 78,
#   'latitude': 27.5142,
#   'longitude': 90.4336,
#   'last_update': 1594787679000},
#  {'id': '114',
#   'country': 'Liechtenstein',
#   'confirmed': 84,
#   'active': 2,
#   'deaths': 1,
#   'recovered': 81,
#   'latitude': 47.14,
#   'longitude': 9.55,
#   'last_update': 1594787679000},
#  {'id': '34',
#   'country': 'Antigua and Barbuda',
#   'confirmed': 74,
#   'active': 14,
#   'deaths': 3,
#   'recovered': 57,
#   'latitude': 17.0608,
#   'longitude': -61.7964,
#   'last_update': 1594787679000},
#  {'id': '83',
#   'country': 'Gambia',
#   'confirmed': 64,
#   'active': 27,
#   'deaths': 3,
#   'recovered': 34,
#   'latitude': 13.4432,
#   'longitude': -15.3101,
#   'last_update': 1594787679000},
#  {'id': '44',
#   'country': 'Belize',
#   'confirmed': 39,
#   'active': 16,
#   'deaths': 2,
#   'recovered': 21,
#   'latitude': 17.1899,
#   'longitude': -88.4976,
#   'last_update': 1594787679000},
#  {'id': '151',
#   'country': 'Saint Vincent and the Grenadines',
#   'confirmed': 35,
#   'active': 6,
#   'deaths': 0,
#   'recovered': 29,
#   'latitude': 12.9843,
#   'longitude': -61.2872,
#   'last_update': 1594787679000},
#  {'id': '81',
#   'country': 'Fiji',
#   'confirmed': 26,
#   'active': 8,
#   'deaths': 0,
#   'recovered': 18,
#   'latitude': -17.7134,
#   'longitude': 178.065,
#   'last_update': 1594787679000},
#  {'id': '173',
#   'country': 'Timor-Leste',
#   'confirmed': 24,
#   'active': 0,
#   'deaths': 0,
#   'recovered': 24,
#   'latitude': -8.874217,
#   'longitude': 125.727539,
#   'last_update': 1594787679000},
#  {'id': '87',
#   'country': 'Grenada',
#   'confirmed': 23,
#   'active': 0,
#   'deaths': 0,
#   'recovered': 23,
#   'latitude': 12.1165,
#   'longitude': -61.679,
#   'last_update': 1594787679000},
#  {'id': '150',
#   'country': 'Saint Lucia',
#   'confirmed': 22,
#   'active': 3,
#   'deaths': 0,
#   'recovered': 19,
#   'latitude': 13.9094,
#   'longitude': -60.9789,
#   'last_update': 1594787679000},
#  {'id': '108',
#   'country': 'Laos',
#   'confirmed': 19,
#   'active': 0,
#   'deaths': 0,
#   'recovered': 19,
#   'latitude': 19.85627,
#   'longitude': 102.495496,
#   'last_update': 1594787679000},
#  {'id': '71',
#   'country': 'Dominica',
#   'confirmed': 18,
#   'active': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'latitude': 15.415,
#   'longitude': -61.371,
#   'last_update': 1594787679000},
#  {'id': '149',
#   'country': 'Saint Kitts and Nevis',
#   'confirmed': 17,
#   'active': 2,
#   'deaths': 0,
#   'recovered': 15,
#   'latitude': 17.357822,
#   'longitude': -62.782998,
#   'last_update': 1594787679000},
#  {'id': '93',
#   'country': 'Holy See',
#   'confirmed': 12,
#   'active': 0,
#   'deaths': 0,
#   'recovered': 12,
#   'latitude': 41.9029,
#   'longitude': 12.4534,
#   'last_update': 1594787679000},
#  {'id': '141',
#   'country': 'Papua New Guinea',
#   'confirmed': 11,
#   'active': 3,
#   'deaths': 0,
#   'recovered': 8,
#   'latitude': -6.314993,
#   'longitude': 143.95555,
#   'last_update': 1594787679000},
#  {'id': '185',
#   'country': 'Western Sahara',
#   'confirmed': 10,
#   'active': 1,
#   'deaths': 1,
#   'recovered': 8,
#   'latitude': 24.2155,
#   'longitude': -12.8858,
#   'last_update': 1594787679000},
#  {'id': '117',
#   'country': 'MS Zaandam',
#   'confirmed': 9,
#   'active': 7,
#   'deaths': 2,
#   'recovered': None,
#   'latitude': None,
#   'longitude': None,
#   'last_update': 1594787679000}]

# %%
#List countries

countries = covid.list_countries()

# %%
#Get Status By Country ID

india_cases = covid.get_status_by_country_id(27)

# %%
#Get Status By Country Name

india_cases = covid.get_status_by_country_name("India")

# %%
#Get Total Active cases
active = covid.get_total_active_cases()

#Get Total Confirmed cases
confirmed = covid.get_total_confirmed_cases()

#Get Total Recovered cases
recovered = covid.get_total_recovered()

#Get Total Deaths
deaths = covid.get_total_deaths()

# %%
#Getting data from Worldometers.info
covid = Covid(source="worldometers")

# %%
#Get Data
covid.get_data()
# Out:
# [{'country': 'North America',
#   'confirmed': 4155819,
#   'new_cases': 10369,
#   'deaths': 189036,
#   'recovered': 1941002,
#   'active': 2025781,
#   'critical': 19778,
#   'new_deaths': 896,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'confirmed': 2995692,
#   'new_cases': 4068,
#   'deaths': 108473,
#   'recovered': 1895638,
#   'active': 991581,
#   'critical': 13640,
#   'new_deaths': 106,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Asia',
#   'confirmed': 3092515,
#   'new_cases': 21763,
#   'deaths': 73158,
#   'recovered': 2170738,
#   'active': 848619,
#   'critical': 19801,
#   'new_deaths': 540,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Europe',
#   'confirmed': 2608449,
#   'new_cases': 9231,
#   'deaths': 197497,
#   'recovered': 1544334,
#   'active': 866618,
#   'critical': 5332,
#   'new_deaths': 221,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Africa',
#   'confirmed': 629909,
#   'new_cases': 1024,
#   'deaths': 13813,
#   'recovered': 318515,
#   'active': 297581,
#   'critical': 989,
#   'new_deaths': 10,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Oceania',
#   'confirmed': 12155,
#   'new_cases': 240,
#   'deaths': 133,
#   'recovered': 9533,
#   'active': 2489,
#   'critical': 28,
#   'new_deaths': 3,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': '0',
#   'confirmed': 721,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 651,
#   'active': 55,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'World',
#   'confirmed': 13495260,
#   'new_cases': 46695,
#   'deaths': 582125,
#   'recovered': 7880411,
#   'active': 5032724,
#   'critical': 59572,
#   'new_deaths': 1776,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1731'),
#   'total_deaths_per_million': Decimal('74.7'),
#   'population': Decimal('0')},
#  {'country': 'USA',
#   'confirmed': 3547413,
#   'new_cases': 2336,
#   'deaths': 139174,
#   'recovered': 1600910,
#   'active': 1807329,
#   'critical': 16337,
#   'new_deaths': 31,
#   'total_tests': 44034024,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10715'),
#   'total_deaths_per_million': Decimal('420'),
#   'population': Decimal('331076384')},
#  {'country': 'Brazil',
#   'confirmed': 1933655,
#   'new_cases': 2451,
#   'deaths': 74336,
#   'recovered': 1213512,
#   'active': 645807,
#   'critical': 8318,
#   'new_deaths': 74,
#   'total_tests': 4572796,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9095'),
#   'total_deaths_per_million': Decimal('350'),
#   'population': Decimal('212615886')},
#  {'country': 'India',
#   'confirmed': 941630,
#   'new_cases': 4143,
#   'deaths': 24371,
#   'recovered': 594111,
#   'active': 323148,
#   'critical': 8944,
#   'new_deaths': 56,
#   'total_tests': 12412664,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('682'),
#   'total_deaths_per_million': Decimal('18'),
#   'population': Decimal('1380493070')},
#  {'country': 'Russia',
#   'confirmed': 746369,
#   'new_cases': 6422,
#   'deaths': 11770,
#   'recovered': 523249,
#   'active': 211350,
#   'critical': 2300,
#   'new_deaths': 156,
#   'total_tests': 23754645,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5114'),
#   'total_deaths_per_million': Decimal('81'),
#   'population': Decimal('145937005')},
#  {'country': 'Peru',
#   'confirmed': 333867,
#   'new_cases': 0,
#   'deaths': 12229,
#   'recovered': 223261,
#   'active': 98377,
#   'critical': 1325,
#   'new_deaths': 0,
#   'total_tests': 1963921,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10121'),
#   'total_deaths_per_million': Decimal('371'),
#   'population': Decimal('32987448')},
#  {'country': 'Chile',
#   'confirmed': 319493,
#   'new_cases': 0,
#   'deaths': 7069,
#   'recovered': 289220,
#   'active': 23204,
#   'critical': 1915,
#   'new_deaths': 0,
#   'total_tests': 1322503,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('16708'),
#   'total_deaths_per_million': Decimal('370'),
#   'population': Decimal('19122213')},
#  {'country': 'Mexico',
#   'confirmed': 311486,
#   'new_cases': 7051,
#   'deaths': 36327,
#   'recovered': 193976,
#   'active': 81183,
#   'critical': 378,
#   'new_deaths': 836,
#   'total_tests': 756137,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2415'),
#   'total_deaths_per_million': Decimal('282'),
#   'population': Decimal('128981086')},
#  {'country': 'Spain',
#   'confirmed': 303699,
#   'new_cases': 0,
#   'deaths': 28409,
#   'recovered': 0,
#   'active': 0,
#   'critical': 617,
#   'new_deaths': 0,
#   'total_tests': 6026446,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6495'),
#   'total_deaths_per_million': Decimal('608'),
#   'population': Decimal('46755514')},
#  {'country': 'South Africa',
#   'confirmed': 298292,
#   'new_cases': 0,
#   'deaths': 4346,
#   'recovered': 146279,
#   'active': 147667,
#   'critical': 539,
#   'new_deaths': 0,
#   'total_tests': 2232738,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5027'),
#   'total_deaths_per_million': Decimal('73'),
#   'population': Decimal('59334579')},
#  {'country': 'UK',
#   'confirmed': 291373,
#   'new_cases': 0,
#   'deaths': 44968,
#   'recovered': 0,
#   'active': 0,
#   'critical': 162,
#   'new_deaths': 0,
#   'total_tests': 12270317,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4291'),
#   'total_deaths_per_million': Decimal('662'),
#   'population': Decimal('67899665')},
#  {'country': 'Iran',
#   'confirmed': 264561,
#   'new_cases': 2388,
#   'deaths': 13410,
#   'recovered': 227561,
#   'active': 23590,
#   'critical': 3411,
#   'new_deaths': 199,
#   'total_tests': 2048049,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3148'),
#   'total_deaths_per_million': Decimal('160'),
#   'population': Decimal('84030066')},
#  {'country': 'Pakistan',
#   'confirmed': 255769,
#   'new_cases': 2165,
#   'deaths': 5386,
#   'recovered': 172810,
#   'active': 77573,
#   'critical': 2078,
#   'new_deaths': 66,
#   'total_tests': 1627939,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1157'),
#   'total_deaths_per_million': Decimal('24'),
#   'population': Decimal('221025870')},
#  {'country': 'Italy',
#   'confirmed': 243344,
#   'new_cases': 0,
#   'deaths': 34984,
#   'recovered': 195441,
#   'active': 12919,
#   'critical': 60,
#   'new_deaths': 0,
#   'total_tests': 6004611,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4025'),
#   'total_deaths_per_million': Decimal('579'),
#   'population': Decimal('60458132')},
#  {'country': 'Saudi Arabia',
#   'confirmed': 237803,
#   'new_cases': 0,
#   'deaths': 2283,
#   'recovered': 177560,
#   'active': 57960,
#   'critical': 2235,
#   'new_deaths': 0,
#   'total_tests': 2336874,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6827'),
#   'total_deaths_per_million': Decimal('66'),
#   'population': Decimal('34831824')},
#  {'country': 'Turkey',
#   'confirmed': 214993,
#   'new_cases': 0,
#   'deaths': 5402,
#   'recovered': 196720,
#   'active': 12871,
#   'critical': 1204,
#   'new_deaths': 0,
#   'total_tests': 4065178,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2548'),
#   'total_deaths_per_million': Decimal('64'),
#   'population': Decimal('84371332')},
#  {'country': 'Germany',
#   'confirmed': 200766,
#   'new_cases': 0,
#   'deaths': 9144,
#   'recovered': 186000,
#   'active': 5622,
#   'critical': 264,
#   'new_deaths': 0,
#   'total_tests': 6376054,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2396'),
#   'total_deaths_per_million': Decimal('109'),
#   'population': Decimal('83794469')},
#  {'country': 'Bangladesh',
#   'confirmed': 193590,
#   'new_cases': 3533,
#   'deaths': 2457,
#   'recovered': 105523,
#   'active': 85610,
#   'critical': 1,
#   'new_deaths': 33,
#   'total_tests': 980402,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1175'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('164748373')},
#  {'country': 'France',
#   'confirmed': 172377,
#   'new_cases': 0,
#   'deaths': 30029,
#   'recovered': 78597,
#   'active': 63751,
#   'critical': 492,
#   'new_deaths': 0,
#   'total_tests': 2489269,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2641'),
#   'total_deaths_per_million': Decimal('460'),
#   'population': Decimal('65279255')},
#  {'country': 'Colombia',
#   'confirmed': 159898,
#   'new_cases': 0,
#   'deaths': 5625,
#   'recovered': 68806,
#   'active': 85467,
#   'critical': 875,
#   'new_deaths': 0,
#   'total_tests': 1082415,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3141'),
#   'total_deaths_per_million': Decimal('111'),
#   'population': Decimal('50902201')},
#  {'country': 'Canada',
#   'confirmed': 108486,
#   'new_cases': 0,
#   'deaths': 8798,
#   'recovered': 72170,
#   'active': 27518,
#   'critical': 2170,
#   'new_deaths': 0,
#   'total_tests': 3302483,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2873'),
#   'total_deaths_per_million': Decimal('233'),
#   'population': Decimal('37754249')},
#  {'country': 'Argentina',
#   'confirmed': 106910,
#   'new_cases': 0,
#   'deaths': 1968,
#   'recovered': 45467,
#   'active': 59475,
#   'critical': 752,
#   'new_deaths': 0,
#   'total_tests': 483799,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2365'),
#   'total_deaths_per_million': Decimal('44'),
#   'population': Decimal('45210848')},
#  {'country': 'Qatar',
#   'confirmed': 104983,
#   'new_cases': 450,
#   'deaths': 151,
#   'recovered': 101637,
#   'active': 3195,
#   'critical': 135,
#   'new_deaths': 1,
#   'total_tests': 424858,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('37390'),
#   'total_deaths_per_million': Decimal('54'),
#   'population': Decimal('2807805')},
#  {'country': 'Egypt',
#   'confirmed': 83930,
#   'new_cases': 0,
#   'deaths': 4008,
#   'recovered': 25544,
#   'active': 54378,
#   'critical': 41,
#   'new_deaths': 0,
#   'total_tests': 135000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('820'),
#   'total_deaths_per_million': Decimal('39'),
#   'population': Decimal('102395050')},
#  {'country': 'Iraq',
#   'confirmed': 81757,
#   'new_cases': 0,
#   'deaths': 3345,
#   'recovered': 50782,
#   'active': 27630,
#   'critical': 412,
#   'new_deaths': 0,
#   'total_tests': 698012,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2031'),
#   'total_deaths_per_million': Decimal('83'),
#   'population': Decimal('40249168')},
#  {'country': 'Indonesia',
#   'confirmed': 80094,
#   'new_cases': 1522,
#   'deaths': 3797,
#   'recovered': 39050,
#   'active': 37247,
#   'critical': 0,
#   'new_deaths': 87,
#   'total_tests': 1122339,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('293'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('273626716')},
#  {'country': 'Sweden',
#   'confirmed': 76001,
#   'new_cases': 0,
#   'deaths': 5545,
#   'recovered': 0,
#   'active': 0,
#   'critical': 81,
#   'new_deaths': 0,
#   'total_tests': 681820,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('7524'),
#   'total_deaths_per_million': Decimal('549'),
#   'population': Decimal('10101646')},
#  {'country': 'Ecuador',
#   'confirmed': 69570,
#   'new_cases': 0,
#   'deaths': 5130,
#   'recovered': 30484,
#   'active': 33956,
#   'critical': 313,
#   'new_deaths': 0,
#   'total_tests': 186879,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3941'),
#   'total_deaths_per_million': Decimal('291'),
#   'population': Decimal('17651979')},
#  {'country': 'Belarus',
#   'confirmed': 65443,
#   'new_cases': 174,
#   'deaths': 480,
#   'recovered': 56379,
#   'active': 8584,
#   'critical': 89,
#   'new_deaths': 6,
#   'total_tests': 1151734,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('6926'),
#   'total_deaths_per_million': Decimal('51'),
#   'population': Decimal('9449196')},
#  {'country': 'Kazakhstan',
#   'confirmed': 63514,
#   'new_cases': 1759,
#   'deaths': 375,
#   'recovered': 38008,
#   'active': 25131,
#   'critical': 221,
#   'new_deaths': 0,
#   'total_tests': 1737546,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3381'),
#   'total_deaths_per_million': Decimal('20'),
#   'population': Decimal('18784556')},
#  {'country': 'Belgium',
#   'confirmed': 62872,
#   'new_cases': 91,
#   'deaths': 9788,
#   'recovered': 17242,
#   'active': 35842,
#   'critical': 27,
#   'new_deaths': 1,
#   'total_tests': 1398080,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5424'),
#   'total_deaths_per_million': Decimal('844'),
#   'population': Decimal('11591576')},
#  {'country': 'Oman',
#   'confirmed': 61247,
#   'new_cases': 1679,
#   'deaths': 281,
#   'recovered': 39038,
#   'active': 21928,
#   'critical': 139,
#   'new_deaths': 8,
#   'total_tests': 253444,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11985'),
#   'total_deaths_per_million': Decimal('55'),
#   'population': Decimal('5110259')},
#  {'country': 'Philippines',
#   'confirmed': 58850,
#   'new_cases': 1392,
#   'deaths': 1614,
#   'recovered': 20976,
#   'active': 36260,
#   'critical': 333,
#   'new_deaths': 11,
#   'total_tests': 1017723,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('537'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('109631056')},
#  {'country': 'Kuwait',
#   'confirmed': 56174,
#   'new_cases': 0,
#   'deaths': 396,
#   'recovered': 46161,
#   'active': 9617,
#   'critical': 156,
#   'new_deaths': 0,
#   'total_tests': 441143,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('13147'),
#   'total_deaths_per_million': Decimal('93'),
#   'population': Decimal('4272688')},
#  {'country': 'Ukraine',
#   'confirmed': 55607,
#   'new_cases': 836,
#   'deaths': 1427,
#   'recovered': 28131,
#   'active': 26049,
#   'critical': 93,
#   'new_deaths': 15,
#   'total_tests': 827157,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1272'),
#   'total_deaths_per_million': Decimal('33'),
#   'population': Decimal('43722282')},
#  {'country': 'UAE',
#   'confirmed': 55573,
#   'new_cases': 0,
#   'deaths': 335,
#   'recovered': 46025,
#   'active': 9213,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 4052000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5617'),
#   'total_deaths_per_million': Decimal('34'),
#   'population': Decimal('9894571')},
#  {'country': 'Netherlands',
#   'confirmed': 51146,
#   'new_cases': 0,
#   'deaths': 6135,
#   'recovered': 0,
#   'active': 0,
#   'critical': 20,
#   'new_deaths': 0,
#   'total_tests': 764079,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2985'),
#   'total_deaths_per_million': Decimal('358'),
#   'population': Decimal('17136380')},
#  {'country': 'Bolivia',
#   'confirmed': 50867,
#   'new_cases': 1617,
#   'deaths': 1898,
#   'recovered': 15819,
#   'active': 33150,
#   'critical': 71,
#   'new_deaths': 32,
#   'total_tests': 111416,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4356'),
#   'total_deaths_per_million': Decimal('163'),
#   'population': Decimal('11678450')},
#  {'country': 'Panama',
#   'confirmed': 48096,
#   'new_cases': 0,
#   'deaths': 960,
#   'recovered': 24667,
#   'active': 22469,
#   'critical': 157,
#   'new_deaths': 0,
#   'total_tests': 171116,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11141'),
#   'total_deaths_per_million': Decimal('222'),
#   'population': Decimal('4317010')},
#  {'country': 'Portugal',
#   'confirmed': 47051,
#   'new_cases': 0,
#   'deaths': 1668,
#   'recovered': 31550,
#   'active': 13833,
#   'critical': 69,
#   'new_deaths': 0,
#   'total_tests': 1366864,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4615'),
#   'total_deaths_per_million': Decimal('164'),
#   'population': Decimal('10195453')},
#  {'country': 'Singapore',
#   'confirmed': 46878,
#   'new_cases': 249,
#   'deaths': 27,
#   'recovered': 42737,
#   'active': 4114,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1009532,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8011'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('5852044')},
#  {'country': 'Dominican Republic',
#   'confirmed': 46305,
#   'new_cases': 0,
#   'deaths': 910,
#   'recovered': 23134,
#   'active': 22261,
#   'critical': 226,
#   'new_deaths': 0,
#   'total_tests': 189391,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4267'),
#   'total_deaths_per_million': Decimal('84'),
#   'population': Decimal('10851818')},
#  {'country': 'Israel',
#   'confirmed': 42813,
#   'new_cases': 453,
#   'deaths': 375,
#   'recovered': 19734,
#   'active': 22704,
#   'critical': 195,
#   'new_deaths': 4,
#   'total_tests': 1317362,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4655'),
#   'total_deaths_per_million': Decimal('41'),
#   'population': Decimal('9197590')},
#  {'country': 'Poland',
#   'confirmed': 38721,
#   'new_cases': 264,
#   'deaths': 1594,
#   'recovered': 28492,
#   'active': 8635,
#   'critical': 73,
#   'new_deaths': 6,
#   'total_tests': 1860592,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1023'),
#   'total_deaths_per_million': Decimal('42'),
#   'population': Decimal('37844896')},
#  {'country': 'Afghanistan',
#   'confirmed': 34994,
#   'new_cases': 254,
#   'deaths': 1094,
#   'recovered': 22456,
#   'active': 11444,
#   'critical': 31,
#   'new_deaths': 46,
#   'total_tests': 81934,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('898'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('38954218')},
#  {'country': 'Romania',
#   'confirmed': 34226,
#   'new_cases': 641,
#   'deaths': 1952,
#   'recovered': 22049,
#   'active': 10225,
#   'critical': 248,
#   'new_deaths': 21,
#   'total_tests': 886918,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1780'),
#   'total_deaths_per_million': Decimal('101'),
#   'population': Decimal('19232044')},
#  {'country': 'Bahrain',
#   'confirmed': 34078,
#   'new_cases': 0,
#   'deaths': 116,
#   'recovered': 29753,
#   'active': 4209,
#   'critical': 46,
#   'new_deaths': 5,
#   'total_tests': 685318,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('20011'),
#   'total_deaths_per_million': Decimal('68'),
#   'population': Decimal('1702931')},
#  {'country': 'Nigeria',
#   'confirmed': 33616,
#   'new_cases': 0,
#   'deaths': 754,
#   'recovered': 13792,
#   'active': 19070,
#   'critical': 7,
#   'new_deaths': 0,
#   'total_tests': 186309,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('163'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('206284260')},
#  {'country': 'Switzerland',
#   'confirmed': 33148,
#   'new_cases': 132,
#   'deaths': 1968,
#   'recovered': 29800,
#   'active': 1380,
#   'critical': 20,
#   'new_deaths': 0,
#   'total_tests': 700326,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3829'),
#   'total_deaths_per_million': Decimal('227'),
#   'population': Decimal('8656981')},
#  {'country': 'Armenia',
#   'confirmed': 33005,
#   'new_cases': 515,
#   'deaths': 592,
#   'recovered': 21348,
#   'active': 11065,
#   'critical': 10,
#   'new_deaths': 11,
#   'total_tests': 139220,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('11137'),
#   'total_deaths_per_million': Decimal('200'),
#   'population': Decimal('2963464')},
#  {'country': 'Guatemala',
#   'confirmed': 30872,
#   'new_cases': 0,
#   'deaths': 1302,
#   'recovered': 4453,
#   'active': 25117,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 64590,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1722'),
#   'total_deaths_per_million': Decimal('73'),
#   'population': Decimal('17926043')},
#  {'country': 'Honduras',
#   'confirmed': 29106,
#   'new_cases': 527,
#   'deaths': 807,
#   'recovered': 3287,
#   'active': 25012,
#   'critical': 58,
#   'new_deaths': 18,
#   'total_tests': 49308,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2937'),
#   'total_deaths_per_million': Decimal('81'),
#   'population': Decimal('9909797')},
#  {'country': 'Ireland',
#   'confirmed': 25670,
#   'new_cases': 0,
#   'deaths': 1746,
#   'recovered': 23364,
#   'active': 560,
#   'critical': 9,
#   'new_deaths': 0,
#   'total_tests': 523277,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5197'),
#   'total_deaths_per_million': Decimal('353'),
#   'population': Decimal('4939736')},
#  {'country': 'Ghana',
#   'confirmed': 25252,
#   'new_cases': 264,
#   'deaths': 139,
#   'recovered': 21397,
#   'active': 3716,
#   'critical': 8,
#   'new_deaths': 0,
#   'total_tests': 331366,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('812'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('31092641')},
#  {'country': 'Azerbaijan',
#   'confirmed': 25113,
#   'new_cases': 0,
#   'deaths': 319,
#   'recovered': 16150,
#   'active': 8644,
#   'critical': 66,
#   'new_deaths': 0,
#   'total_tests': 576249,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2476'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('10142506')},
#  {'country': 'Japan',
#   'confirmed': 22220,
#   'new_cases': 0,
#   'deaths': 982,
#   'recovered': 18282,
#   'active': 2956,
#   'critical': 40,
#   'new_deaths': 0,
#   'total_tests': 574432,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('176'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('126460083')},
#  {'country': 'Algeria',
#   'confirmed': 20216,
#   'new_cases': 0,
#   'deaths': 1028,
#   'recovered': 14295,
#   'active': 4893,
#   'critical': 61,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('461'),
#   'total_deaths_per_million': Decimal('23'),
#   'population': Decimal('43876253')},
#  {'country': 'Moldova',
#   'confirmed': 19708,
#   'new_cases': 0,
#   'deaths': 658,
#   'recovered': 13298,
#   'active': 5752,
#   'critical': 358,
#   'new_deaths': 3,
#   'total_tests': 101180,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('4886'),
#   'total_deaths_per_million': Decimal('163'),
#   'population': Decimal('4033570')},
#  {'country': 'Austria',
#   'confirmed': 19154,
#   'new_cases': 133,
#   'deaths': 710,
#   'recovered': 17175,
#   'active': 1269,
#   'critical': 10,
#   'new_deaths': 1,
#   'total_tests': 716293,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2126'),
#   'total_deaths_per_million': Decimal('79'),
#   'population': Decimal('9008354')},
#  {'country': 'Serbia',
#   'confirmed': 18983,
#   'new_cases': 0,
#   'deaths': 418,
#   'recovered': 13991,
#   'active': 4574,
#   'critical': 170,
#   'new_deaths': 0,
#   'total_tests': 507002,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2173'),
#   'total_deaths_per_million': Decimal('48'),
#   'population': Decimal('8735866')},
#  {'country': 'Nepal',
#   'confirmed': 17177,
#   'new_cases': 116,
#   'deaths': 39,
#   'recovered': 11025,
#   'active': 6113,
#   'critical': 0,
#   'new_deaths': 1,
#   'total_tests': 611231,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('589'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('29153511')},
#  {'country': 'Morocco',
#   'confirmed': 16181,
#   'new_cases': 84,
#   'deaths': 258,
#   'recovered': 13666,
#   'active': 2257,
#   'critical': 31,
#   'new_deaths': 1,
#   'total_tests': 924695,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('438'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('36925874')},
#  {'country': 'Cameroon',
#   'confirmed': 15173,
#   'new_cases': 0,
#   'deaths': 359,
#   'recovered': 11928,
#   'active': 2886,
#   'critical': 52,
#   'new_deaths': 0,
#   'total_tests': 120837,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('571'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('26564536')},
#  {'country': 'Uzbekistan',
#   'confirmed': 14293,
#   'new_cases': 208,
#   'deaths': 68,
#   'recovered': 8327,
#   'active': 5898,
#   'critical': 43,
#   'new_deaths': 1,
#   'total_tests': 1377915,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('427'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('33485533')},
#  {'country': 'S. Korea',
#   'confirmed': 13551,
#   'new_cases': 39,
#   'deaths': 289,
#   'recovered': 12348,
#   'active': 914,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 1431316,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('264'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('51270969')},
#  {'country': 'Czechia',
#   'confirmed': 13341,
#   'new_cases': 0,
#   'deaths': 355,
#   'recovered': 8441,
#   'active': 4545,
#   'critical': 21,
#   'new_deaths': 0,
#   'total_tests': 602670,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1246'),
#   'total_deaths_per_million': Decimal('33'),
#   'population': Decimal('10709775')},
#  {'country': 'Denmark',
#   'confirmed': 13061,
#   'new_cases': 0,
#   'deaths': 610,
#   'recovered': 12160,
#   'active': 291,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 1257157,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2255'),
#   'total_deaths_per_million': Decimal('105'),
#   'population': Decimal('5793000')},
#  {'country': 'Ivory Coast',
#   'confirmed': 13037,
#   'new_cases': 0,
#   'deaths': 87,
#   'recovered': 6908,
#   'active': 6042,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 78066,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('494'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('26396778')},
#  {'country': 'Kyrgyzstan',
#   'confirmed': 11977,
#   'new_cases': 533,
#   'deaths': 160,
#   'recovered': 3660,
#   'active': 8157,
#   'critical': 24,
#   'new_deaths': 11,
#   'total_tests': 259793,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1835'),
#   'total_deaths_per_million': Decimal('25'),
#   'population': Decimal('6527708')},
#  {'country': 'Kenya',
#   'confirmed': 10791,
#   'new_cases': 0,
#   'deaths': 202,
#   'recovered': 3017,
#   'active': 7572,
#   'critical': 44,
#   'new_deaths': 0,
#   'total_tests': 221234,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('201'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('53806557')},
#  {'country': 'El Salvador',
#   'confirmed': 10645,
#   'new_cases': 342,
#   'deaths': 286,
#   'recovered': 6120,
#   'active': 4239,
#   'critical': 398,
#   'new_deaths': 8,
#   'total_tests': 199637,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1641'),
#   'total_deaths_per_million': Decimal('44'),
#   'population': Decimal('6487461')},
#  {'country': 'Australia',
#   'confirmed': 10487,
#   'new_cases': 237,
#   'deaths': 111,
#   'recovered': 7928,
#   'active': 2448,
#   'critical': 28,
#   'new_deaths': 3,
#   'total_tests': 3213715,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('411'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('25510278')},
#  {'country': 'Sudan',
#   'confirmed': 10417,
#   'new_cases': 0,
#   'deaths': 659,
#   'recovered': 5579,
#   'active': 4179,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 401,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('237'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('43879028')},
#  {'country': 'Venezuela',
#   'confirmed': 10010,
#   'new_cases': 0,
#   'deaths': 96,
#   'recovered': 2671,
#   'active': 7243,
#   'critical': 25,
#   'new_deaths': 0,
#   'total_tests': 1386563,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('352'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('28432540')},
#  {'country': 'Norway',
#   'confirmed': 9001,
#   'new_cases': 0,
#   'deaths': 253,
#   'recovered': 8138,
#   'active': 610,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 383149,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1660'),
#   'total_deaths_per_million': Decimal('47'),
#   'population': Decimal('5422810')},
#  {'country': 'Malaysia',
#   'confirmed': 8734,
#   'new_cases': 5,
#   'deaths': 122,
#   'recovered': 8526,
#   'active': 86,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 861896,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('270'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('32380313')},
#  {'country': 'Costa Rica',
#   'confirmed': 8482,
#   'new_cases': 0,
#   'deaths': 37,
#   'recovered': 2441,
#   'active': 6004,
#   'critical': 30,
#   'new_deaths': 1,
#   'total_tests': 61216,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1665'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('5095810')},
#  {'country': 'Senegal',
#   'confirmed': 8369,
#   'new_cases': 126,
#   'deaths': 153,
#   'recovered': 5605,
#   'active': 2611,
#   'critical': 37,
#   'new_deaths': 3,
#   'total_tests': 92905,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('499'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('16756053')},
#  {'country': 'North Macedonia',
#   'confirmed': 8332,
#   'new_cases': 0,
#   'deaths': 389,
#   'recovered': 4468,
#   'active': 3475,
#   'critical': 55,
#   'new_deaths': 0,
#   'total_tests': 79392,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3999'),
#   'total_deaths_per_million': Decimal('187'),
#   'population': Decimal('2083371')},
#  {'country': 'DRC',
#   'confirmed': 8163,
#   'new_cases': 28,
#   'deaths': 192,
#   'recovered': 3983,
#   'active': 3988,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('91'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('89630305')},
#  {'country': 'Ethiopia',
#   'confirmed': 7969,
#   'new_cases': 0,
#   'deaths': 139,
#   'recovered': 2430,
#   'active': 5400,
#   'critical': 35,
#   'new_deaths': 0,
#   'total_tests': 250604,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('69'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('115044244')},
#  {'country': 'Bulgaria',
#   'confirmed': 7645,
#   'new_cases': 0,
#   'deaths': 283,
#   'recovered': 3663,
#   'active': 3699,
#   'critical': 27,
#   'new_deaths': 0,
#   'total_tests': 184560,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1101'),
#   'total_deaths_per_million': Decimal('41'),
#   'population': Decimal('6946122')},
#  {'country': 'Bosnia and Herzegovina',
#   'confirmed': 7411,
#   'new_cases': 306,
#   'deaths': 235,
#   'recovered': 3335,
#   'active': 3841,
#   'critical': 0,
#   'new_deaths': 8,
#   'total_tests': 114344,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2260'),
#   'total_deaths_per_million': Decimal('72'),
#   'population': Decimal('3279925')},
#  {'country': 'Finland',
#   'confirmed': 7296,
#   'new_cases': 0,
#   'deaths': 328,
#   'recovered': 6880,
#   'active': 88,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 291100,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1317'),
#   'total_deaths_per_million': Decimal('59'),
#   'population': Decimal('5541065')},
#  {'country': 'Palestine',
#   'confirmed': 7064,
#   'new_cases': 300,
#   'deaths': 44,
#   'recovered': 1084,
#   'active': 5936,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 141444,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1384'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('5104868')},
#  {'country': 'Haiti',
#   'confirmed': 6831,
#   'new_cases': 104,
#   'deaths': 143,
#   'recovered': 3283,
#   'active': 3405,
#   'critical': 0,
#   'new_deaths': 2,
#   'total_tests': 14544,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('599'),
#   'total_deaths_per_million': Decimal('13'),
#   'population': Decimal('11407370')},
#  {'country': 'Tajikistan',
#   'confirmed': 6643,
#   'new_cases': 0,
#   'deaths': 56,
#   'recovered': 5332,
#   'active': 1255,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('696'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('9543974')},
#  {'country': 'French Guiana',
#   'confirmed': 6229,
#   'new_cases': 0,
#   'deaths': 31,
#   'recovered': 3472,
#   'active': 2726,
#   'critical': 25,
#   'new_deaths': 0,
#   'total_tests': 11273,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('20840'),
#   'total_deaths_per_million': Decimal('104'),
#   'population': Decimal('298897')},
#  {'country': 'Guinea',
#   'confirmed': 6200,
#   'new_cases': 0,
#   'deaths': 38,
#   'recovered': 4951,
#   'active': 1211,
#   'critical': 24,
#   'new_deaths': 0,
#   'total_tests': 14407,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('472'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('13142438')},
#  {'country': 'Gabon',
#   'confirmed': 6026,
#   'new_cases': 0,
#   'deaths': 46,
#   'recovered': 3475,
#   'active': 2505,
#   'critical': 11,
#   'new_deaths': 0,
#   'total_tests': 49853,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2706'),
#   'total_deaths_per_million': Decimal('21'),
#   'population': Decimal('2227254')},
#  {'country': 'Madagascar',
#   'confirmed': 5605,
#   'new_cases': 262,
#   'deaths': 43,
#   'recovered': 2811,
#   'active': 2751,
#   'critical': 51,
#   'new_deaths': 4,
#   'total_tests': 30530,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('202'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('27710827')},
#  {'country': 'Mauritania',
#   'confirmed': 5518,
#   'new_cases': 0,
#   'deaths': 147,
#   'recovered': 2664,
#   'active': 2707,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 13842,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1186'),
#   'total_deaths_per_million': Decimal('32'),
#   'population': Decimal('4653021')},
#  {'country': 'Luxembourg',
#   'confirmed': 5056,
#   'new_cases': 0,
#   'deaths': 111,
#   'recovered': 4195,
#   'active': 750,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 292711,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('8073'),
#   'total_deaths_per_million': Decimal('177'),
#   'population': Decimal('626312')},
#  {'country': 'Djibouti',
#   'confirmed': 4979,
#   'new_cases': 0,
#   'deaths': 56,
#   'recovered': 4743,
#   'active': 180,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 51843,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5037'),
#   'total_deaths_per_million': Decimal('57'),
#   'population': Decimal('988483')},
#  {'country': 'CAR',
#   'confirmed': 4356,
#   'new_cases': 0,
#   'deaths': 53,
#   'recovered': 1229,
#   'active': 3074,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 27561,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('901'),
#   'total_deaths_per_million': Decimal('11'),
#   'population': Decimal('4832469')},
#  {'country': 'Hungary',
#   'confirmed': 4263,
#   'new_cases': 5,
#   'deaths': 595,
#   'recovered': 3126,
#   'active': 542,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 299185,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('441'),
#   'total_deaths_per_million': Decimal('62'),
#   'population': Decimal('9659319')},
#  {'country': 'Croatia',
#   'confirmed': 3953,
#   'new_cases': 92,
#   'deaths': 120,
#   'recovered': 2629,
#   'active': 1204,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 97724,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('963'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('4104159')},
#  {'country': 'Greece',
#   'confirmed': 3883,
#   'new_cases': 0,
#   'deaths': 193,
#   'recovered': 1374,
#   'active': 2316,
#   'critical': 13,
#   'new_deaths': 0,
#   'total_tests': 386307,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('373'),
#   'total_deaths_per_million': Decimal('19'),
#   'population': Decimal('10420856')},
#  {'country': 'Albania',
#   'confirmed': 3752,
#   'new_cases': 85,
#   'deaths': 101,
#   'recovered': 2091,
#   'active': 1560,
#   'critical': 10,
#   'new_deaths': 4,
#   'total_tests': 29695,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1304'),
#   'total_deaths_per_million': Decimal('35'),
#   'population': Decimal('2877667')},
#  {'country': 'Thailand',
#   'confirmed': 3232,
#   'new_cases': 5,
#   'deaths': 58,
#   'recovered': 3092,
#   'active': 82,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 603657,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('46'),
#   'total_deaths_per_million': Decimal('0.8'),
#   'population': Decimal('69806919')},
#  {'country': 'Nicaragua',
#   'confirmed': 3147,
#   'new_cases': 0,
#   'deaths': 99,
#   'recovered': 2282,
#   'active': 766,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('475'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('6627311')},
#  {'country': 'Somalia',
#   'confirmed': 3076,
#   'new_cases': 0,
#   'deaths': 93,
#   'recovered': 1380,
#   'active': 1603,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('193'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('15905041')},
#  {'country': 'Paraguay',
#   'confirmed': 3074,
#   'new_cases': 0,
#   'deaths': 25,
#   'recovered': 1308,
#   'active': 1741,
#   'critical': 10,
#   'new_deaths': 0,
#   'total_tests': 94328,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('431'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('7135586')},
#  {'country': 'Equatorial Guinea',
#   'confirmed': 3071,
#   'new_cases': 0,
#   'deaths': 51,
#   'recovered': 842,
#   'active': 2178,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 16000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2187'),
#   'total_deaths_per_million': Decimal('36'),
#   'population': Decimal('1404090')},
#  {'country': 'Maldives',
#   'confirmed': 2801,
#   'new_cases': 0,
#   'deaths': 14,
#   'recovered': 2302,
#   'active': 485,
#   'critical': 12,
#   'new_deaths': 0,
#   'total_tests': 63559,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5179'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('540849')},
#  {'country': 'Mayotte',
#   'confirmed': 2724,
#   'new_cases': 0,
#   'deaths': 37,
#   'recovered': 2480,
#   'active': 207,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 13000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('9978'),
#   'total_deaths_per_million': Decimal('136'),
#   'population': Decimal('273004')},
#  {'country': 'Sri Lanka',
#   'confirmed': 2665,
#   'new_cases': 0,
#   'deaths': 11,
#   'recovered': 1988,
#   'active': 666,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 127920,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('124'),
#   'total_deaths_per_million': Decimal('0.5'),
#   'population': Decimal('21416733')},
#  {'country': 'Malawi',
#   'confirmed': 2497,
#   'new_cases': 0,
#   'deaths': 40,
#   'recovered': 795,
#   'active': 1662,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 21532,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('130'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('19143672')},
#  {'country': 'Lebanon',
#   'confirmed': 2451,
#   'new_cases': 0,
#   'deaths': 37,
#   'recovered': 1452,
#   'active': 962,
#   'critical': 20,
#   'new_deaths': 0,
#   'total_tests': 184425,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('359'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('6824132')},
#  {'country': 'Cuba',
#   'confirmed': 2432,
#   'new_cases': 0,
#   'deaths': 87,
#   'recovered': 2275,
#   'active': 70,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 211427,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('215'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('11326332')},
#  {'country': 'Mali',
#   'confirmed': 2423,
#   'new_cases': 0,
#   'deaths': 121,
#   'recovered': 1748,
#   'active': 554,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 16317,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('120'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('20266097')},
#  {'country': 'Congo',
#   'confirmed': 2222,
#   'new_cases': 194,
#   'deaths': 47,
#   'recovered': 589,
#   'active': 1586,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('402'),
#   'total_deaths_per_million': Decimal('9'),
#   'population': Decimal('5521945')},
#  {'country': 'South Sudan',
#   'confirmed': 2153,
#   'new_cases': 5,
#   'deaths': 41,
#   'recovered': 1175,
#   'active': 937,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 12044,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('192'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('11198327')},
#  {'country': 'Estonia',
#   'confirmed': 2016,
#   'new_cases': 1,
#   'deaths': 69,
#   'recovered': 1901,
#   'active': 46,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 113129,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1520'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('1326571')},
#  {'country': 'Slovakia',
#   'confirmed': 1927,
#   'new_cases': 19,
#   'deaths': 28,
#   'recovered': 1507,
#   'active': 392,
#   'critical': 2,
#   'new_deaths': 0,
#   'total_tests': 233436,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('353'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('5459749')},
#  {'country': 'Iceland',
#   'confirmed': 1905,
#   'new_cases': 0,
#   'deaths': 10,
#   'recovered': 1882,
#   'active': 13,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 104713,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5581'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('341326')},
#  {'country': 'Zambia',
#   'confirmed': 1895,
#   'new_cases': 0,
#   'deaths': 42,
#   'recovered': 1412,
#   'active': 441,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 56825,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('103'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('18397649')},
#  {'country': 'Lithuania',
#   'confirmed': 1882,
#   'new_cases': 7,
#   'deaths': 79,
#   'recovered': 1582,
#   'active': 221,
#   'critical': 15,
#   'new_deaths': 0,
#   'total_tests': 465396,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('692'),
#   'total_deaths_per_million': Decimal('29'),
#   'population': Decimal('2720490')},
#  {'country': 'Slovenia',
#   'confirmed': 1878,
#   'new_cases': 19,
#   'deaths': 111,
#   'recovered': 1501,
#   'active': 266,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 118353,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('903'),
#   'total_deaths_per_million': Decimal('53'),
#   'population': Decimal('2078950')},
#  {'country': 'Guinea-Bissau',
#   'confirmed': 1842,
#   'new_cases': 0,
#   'deaths': 26,
#   'recovered': 773,
#   'active': 1043,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 1500,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('935'),
#   'total_deaths_per_million': Decimal('13'),
#   'population': Decimal('1969346')},
#  {'country': 'Cabo Verde',
#   'confirmed': 1780,
#   'new_cases': 58,
#   'deaths': 19,
#   'recovered': 850,
#   'active': 911,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 41091,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3200'),
#   'total_deaths_per_million': Decimal('34'),
#   'population': Decimal('556201')},
#  {'country': 'Sierra Leone',
#   'confirmed': 1651,
#   'new_cases': 0,
#   'deaths': 64,
#   'recovered': 1190,
#   'active': 397,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('207'),
#   'total_deaths_per_million': Decimal('8'),
#   'population': Decimal('7981956')},
#  {'country': 'Hong Kong',
#   'confirmed': 1589,
#   'new_cases': 19,
#   'deaths': 8,
#   'recovered': 1241,
#   'active': 340,
#   'critical': 6,
#   'new_deaths': 0,
#   'total_tests': 376645,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('212'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('7499224')},
#  {'country': 'Libya',
#   'confirmed': 1563,
#   'new_cases': 0,
#   'deaths': 42,
#   'recovered': 370,
#   'active': 1151,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 36524,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('227'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('6874480')},
#  {'country': 'New Zealand',
#   'confirmed': 1547,
#   'new_cases': 2,
#   'deaths': 22,
#   'recovered': 1498,
#   'active': 27,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 433324,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('309'),
#   'total_deaths_per_million': Decimal('4'),
#   'population': Decimal('5002100')},
#  {'country': 'Yemen',
#   'confirmed': 1516,
#   'new_cases': 0,
#   'deaths': 429,
#   'recovered': 685,
#   'active': 402,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 120,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('51'),
#   'total_deaths_per_million': Decimal('14'),
#   'population': Decimal('29845521')},
#  {'country': 'Eswatini',
#   'confirmed': 1434,
#   'new_cases': 0,
#   'deaths': 20,
#   'recovered': 695,
#   'active': 719,
#   'critical': 5,
#   'new_deaths': 0,
#   'total_tests': 17559,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1236'),
#   'total_deaths_per_million': Decimal('17'),
#   'population': Decimal('1160594')},
#  {'country': 'Rwanda',
#   'confirmed': 1416,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 737,
#   'active': 675,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 192379,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('109'),
#   'total_deaths_per_million': Decimal('0.3'),
#   'population': Decimal('12961309')},
#  {'country': 'Benin',
#   'confirmed': 1378,
#   'new_cases': 0,
#   'deaths': 26,
#   'recovered': 557,
#   'active': 795,
#   'critical': 1,
# ...
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 107,
#   'active': 125,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('65'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3548090')},
#  {'country': 'Cayman Islands',
#   'confirmed': 203,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 200,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 26919,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3087'),
#   'total_deaths_per_million': Decimal('15'),
#   'population': Decimal('65749')},
#  {'country': 'Guadeloupe',
#   'confirmed': 190,
#   'new_cases': 0,
#   'deaths': 14,
#   'recovered': 157,
#   'active': 19,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 11538,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('475'),
#   'total_deaths_per_million': Decimal('35'),
#   'population': Decimal('400127')},
#  {'country': 'Faeroe Islands',
#   'confirmed': 188,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 188,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 24704,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3847'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('48870')},
#  {'country': 'Gibraltar',
#   'confirmed': 180,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 180,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 16789,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('5343'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('33691')},
#  {'country': 'Cambodia',
#   'confirmed': 165,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 133,
#   'active': 32,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 47702,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('10'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('16726831')},
#  {'country': 'Bermuda',
#   'confirmed': 150,
#   'new_cases': 0,
#   'deaths': 9,
#   'recovered': 137,
#   'active': 4,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 14467,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2409'),
#   'total_deaths_per_million': Decimal('145'),
#   'population': Decimal('62268')},
#  {'country': 'Brunei',
#   'confirmed': 141,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 138,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 34797,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('322'),
#   'total_deaths_per_million': Decimal('7'),
#   'population': Decimal('437630')},
#  {'country': 'Trinidad and Tobago',
#   'confirmed': 133,
#   'new_cases': 0,
#   'deaths': 8,
#   'recovered': 124,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 5847,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('95'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('1399666')},
#  {'country': 'Bahamas',
#   'confirmed': 116,
#   'new_cases': 3,
#   'deaths': 11,
#   'recovered': 91,
#   'active': 14,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 2545,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('295'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('393380')},
#  {'country': 'Monaco',
#   'confirmed': 109,
#   'new_cases': 0,
#   'deaths': 4,
#   'recovered': 97,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 16200,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2777'),
#   'total_deaths_per_million': Decimal('102'),
#   'population': Decimal('39252')},
#  {'country': 'Aruba',
#   'confirmed': 106,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 99,
#   'active': 4,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4012,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('993'),
#   'total_deaths_per_million': Decimal('28'),
#   'population': Decimal('106784')},
#  {'country': 'Barbados',
#   'confirmed': 103,
#   'new_cases': 0,
#   'deaths': 7,
#   'recovered': 90,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 9026,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('358'),
#   'total_deaths_per_million': Decimal('24'),
#   'population': Decimal('287389')},
#  {'country': 'Seychelles',
#   'confirmed': 100,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 27,
#   'active': 73,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1017'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('98370')},
#  {'country': 'Liechtenstein',
#   'confirmed': 84,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 81,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 900,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2203'),
#   'total_deaths_per_million': Decimal('26'),
#   'population': Decimal('38132')},
#  {'country': 'Bhutan',
#   'confirmed': 84,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 78,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 39270,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('109'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('771909')},
#  {'country': 'Sint Maarten',
#   'confirmed': 78,
#   'new_cases': 0,
#   'deaths': 15,
#   'recovered': 63,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 523,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1818'),
#   'total_deaths_per_million': Decimal('350'),
#   'population': Decimal('42893')},
#  {'country': 'Antigua and Barbuda',
#   'confirmed': 74,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 57,
#   'active': 14,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 866,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('755'),
#   'total_deaths_per_million': Decimal('31'),
#   'population': Decimal('97959')},
#  {'country': 'Turks and Caicos',
#   'confirmed': 72,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 12,
#   'active': 58,
#   'critical': 4,
#   'new_deaths': 0,
#   'total_tests': 946,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1859'),
#   'total_deaths_per_million': Decimal('52'),
#   'population': Decimal('38735')},
#  {'country': 'Gambia',
#   'confirmed': 64,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 34,
#   'active': 27,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 3573,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('26'),
#   'total_deaths_per_million': Decimal('1'),
#   'population': Decimal('2418471')},
#  {'country': 'French Polynesia',
#   'confirmed': 62,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 60,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4649,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('221'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('280970')},
#  {'country': 'Macao',
#   'confirmed': 46,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 45,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4071,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('71'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('649637')},
#  {'country': 'Saint Martin',
#   'confirmed': 43,
#   'new_cases': 0,
#   'deaths': 3,
#   'recovered': 37,
#   'active': 3,
#   'critical': 1,
#   'new_deaths': 0,
#   'total_tests': 851,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1111'),
#   'total_deaths_per_million': Decimal('78'),
#   'population': Decimal('38687')},
#  {'country': 'Belize',
#   'confirmed': 39,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 21,
#   'active': 16,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2665,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('98'),
#   'total_deaths_per_million': Decimal('5'),
#   'population': Decimal('397857')},
#  {'country': 'St. Vincent Grenadines',
#   'confirmed': 35,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 29,
#   'active': 6,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1213,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('315'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('110954')},
#  {'country': 'Curaçao',
#   'confirmed': 26,
#   'new_cases': 1,
#   'deaths': 1,
#   'recovered': 24,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1080,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('158'),
#   'total_deaths_per_million': Decimal('6'),
#   'population': Decimal('164119')},
#  {'country': 'Fiji',
#   'confirmed': 26,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 8,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('29'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('896687')},
#  {'country': 'Timor-Leste',
#   'confirmed': 24,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 24,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1568,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('18'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('1319232')},
#  {'country': 'Grenada',
#   'confirmed': 23,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 23,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 5465,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('204'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('112543')},
#  {'country': 'New Caledonia',
#   'confirmed': 22,
#   'new_cases': 1,
#   'deaths': 0,
#   'recovered': 21,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 9424,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('77'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('285597')},
#  {'country': 'Saint Lucia',
#   'confirmed': 22,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 19,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 2048,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('120'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('183659')},
#  {'country': 'Laos',
#   'confirmed': 19,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 19,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 21386,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('7279113')},
#  {'country': 'Dominica',
#   'confirmed': 18,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 18,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 623,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('250'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('71993')},
#  {'country': 'Saint Kitts and Nevis',
#   'confirmed': 17,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 15,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 671,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('319'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('53213')},
#  {'country': 'Falkland Islands',
#   'confirmed': 13,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 13,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 1393,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('3732'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('3483')},
#  {'country': 'Greenland',
#   'confirmed': 13,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 13,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 4932,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('229'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('56774')},
#  {'country': 'Montserrat',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 10,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 61,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('2404'),
#   'total_deaths_per_million': Decimal('200'),
#   'population': Decimal('4992')},
#  {'country': 'Vatican City',
#   'confirmed': 12,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 12,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('14981'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('801')},
#  {'country': 'Papua New Guinea',
#   'confirmed': 11,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 8,
#   'active': 3,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 7147,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('1'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('8952342')},
#  {'country': 'Western Sahara',
#   'confirmed': 10,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 8,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('17'),
#   'total_deaths_per_million': Decimal('2'),
#   'population': Decimal('597756')},
#  {'country': 'MS Zaandam',
#   'confirmed': 9,
#   'new_cases': 0,
#   'deaths': 2,
#   'recovered': 0,
#   'active': 7,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Caribbean Netherlands',
#   'confirmed': 9,
#   'new_cases': 2,
#   'deaths': 0,
#   'recovered': 7,
#   'active': 2,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 424,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('343'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('26232')},
#  {'country': 'British Virgin Islands',
#   'confirmed': 8,
#   'new_cases': 0,
#   'deaths': 1,
#   'recovered': 7,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 439,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('265'),
#   'total_deaths_per_million': Decimal('33'),
#   'population': Decimal('30239')},
#  {'country': 'St. Barth',
#   'confirmed': 6,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 6,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 507,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('607'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('9878')},
#  {'country': 'Anguilla',
#   'confirmed': 3,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 3,
#   'active': 0,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 380,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('200'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('15008')},
#  {'country': 'Saint Pierre Miquelon',
#   'confirmed': 2,
#   'new_cases': 0,
#   'deaths': 0,
#   'recovered': 1,
#   'active': 1,
#   'critical': 0,
#   'new_deaths': 0,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('345'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('5793')},
#  {'country': 'China',
#   'confirmed': 83611,
#   'new_cases': 6,
#   'deaths': 4634,
#   'recovered': 78693,
#   'active': 284,
#   'critical': 3,
#   'new_deaths': 0,
#   'total_tests': 90410000,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('58'),
#   'total_deaths_per_million': Decimal('3'),
#   'population': Decimal('1439323776')}]
